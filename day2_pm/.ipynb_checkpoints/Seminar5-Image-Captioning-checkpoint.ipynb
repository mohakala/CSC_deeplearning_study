# %% [markdown]
# DeepLarning Couse HSE 2016 fall:
# * Arseniy Ashuha, you can text me ```ars.ashuha@gmail.com```,
# * ```https://vk.com/ars.ashuha```
# * partially reusing https://github.com/ebenolson/pydata2015
#
# <h1 align="center"> Image Captioning </h1>
#
# In this seminar you'll be going through the image captioning pipeline.
#
# To begin with, let us download the dataset of image features from a pre-trained GoogleNet.

# %%
###
### Or alternatevely
### !wget https://www.dropbox.com/s/3hj16b0fj6yw7cc/data.tar.gz?dl=1 -O data.tar.gz
### !tar -xvzf data.tar.gz
###

DATA_DIR = '/wrk/trng103/'

# %% [markdown]
# ### Data preprocessing

# %%
# %%time
# Read Dataset
import numpy as np
import os.path as osp
import pickle

img_codes = np.load(osp.join(DATA_DIR, "data/image_codes.npy"))
captions = pickle.load(open(osp.join(DATA_DIR, 'data/caption_tokens.pcl'), 'rb'))
# Out:
# CPU times: user 527 ms, sys: 324 ms, total: 851 ms
# Wall time: 1.05 s

# %%
print ("each image code is a 1000-unit vector:", img_codes.shape)
print (img_codes[0,:10])
print ('\n\n')
print ("for each image there are 5-7 descriptions, e.g.:\n")
print ('\n'.join(captions[0]))
# Out:
# each image code is a 1000-unit vector: (123287, 1000)
# [ 1.38901556 -3.82951474 -1.94360816 -0.5317238  -0.03120959 -2.87483215
#  -2.9554503   0.6960277  -0.68551242 -0.7855981 ]
#
#
#
# for each image there are 5-7 descriptions, e.g.:
#
# a man with a red helmet on a small moped on a dirt road
# man riding a motor bike on a dirt road on the countryside
# a man riding on the back of a motorcycle
# a dirt path with a young person on a motor bike rests to the foreground of a verdant area with a bridge and a background of cloud wreathed mountains
# a man in a red shirt and a red hat is on a motorcycle on a hill side

# %%
#split descriptions into tokens
for img_i in range(len(captions)):
    for caption_i in range(len(captions[img_i])):
        sentence = captions[img_i][caption_i] 
        captions[img_i][caption_i] = ["#START#"]+sentence.split(' ')+["#END#"]

# %%
# Build a Vocabulary
from collections import Counter
word_counts = Counter()

#<Compute word frequencies for each word in captions. See code above for data structure>
# tip:
#word_counts.update(captions[0][0])

for img_i in range(len(captions)):
    for caption_i in range(len(captions[img_i])):
        sentence = captions[img_i][caption_i] 
        word_counts.update(sentence)

print(word_counts)
# Out:
# Counter({'a': 1019785, '#END#': 616767, '#START#': 616767, 'on': 224758, 'of': 212689, 'the': 206178, 'in': 191793, 'with': 161216, 'and': 146755, 'is': 102390, 'man': 75957, 'to': 71183, 'sitting': 55190, 'an': 51987, 'two': 50467, 'at': 44506, 'standing': 44297, 'people': 43707, 'are': 42776, 'next': 38867, 'white': 37898, 'woman': 35372, 'street': 31572, 'table': 31444, 'that': 29168, 'holding': 29106, 'large': 25614, 'it': 25608, 'person': 25432, 'some': 25385, 'down': 24038, 'top': 23254, 'group': 22551, 'up': 22425, 'field': 21659, 'small': 20892, 'tennis': 20556, 'near': 20432, 'front': 20342, 'black': 20288, 'his': 20242, 'train': 19464, 'plate': 19183, 'room': 19067, 'riding': 18841, 'dog': 18839, 'red': 18110, 'cat': 17908, 'young': 17804, 'by': 17762, 'water': 17096, 'baseball': 16323, 'has': 15818, 'playing': 15354, 'while': 15278, 'walking': 15182, 'bathroom': 15036, 'sign': 14666, 'blue': 14340, 'kitchen': 13917, 'food': 13851, 'grass': 13559, 'bus': 13372, 'there': 13282, 'green': 13175, 'pizza': 13129, 'side': 13109, 'parked': 13065, 'building': 12980, 'other': 12686, 'bed': 12526, 'looking': 12486, 'snow': 12325, 'beach': 11868, 'ball': 11778, 'couple': 11534, 'three': 11486, 'for': 11431, 'boy': 11281, 'toilet': 11081, 'men': 11032, 'clock': 11008, 'city': 10800, 'road': 10705, 'flying': 10561, 'wearing': 10369, 'out': 10335, 'her': 10333, 'skateboard': 10172, 'player': 10169, 'over': 10064, 'game': 9987, 'several': 9878, 'from': 9739, 'girl': 9729, 'laying': 9728, 'sits': 9694, 'wooden': 9363, 'bench': 9321, 'picture': 9297, 'area': 9138, 'bear': 9111, 'laptop': 9073, 'one': 9039, 'their': 9009, 'through': 8987, 'around': 8835, 'horse': 8797, 'eating': 8759, 'brown': 8756, 'yellow': 8744, 'its': 8720, 'cake': 8686, 'computer': 8576, 'phone': 8536, 'frisbee': 8377, 'sink': 8364, 'board': 8350, 'giraffe': 8228, 'outside': 8156, 'as': 7993, 'living': 7927, 'air': 7887, 'truck': 7795, 'desk': 7726, 'window': 7658, 'motorcycle': 7553, 'close': 7545, 'umbrella': 7444, 'trees': 7394, 'covered': 7392, 'tree': 7384, 'car': 7334, 'open': 7333, 'wall': 7322, 'each': 7271, 'many': 7227, 'park': 7195, 'elephant': 7086, 'old': 7037, 'this': 7028, 'very': 7025, 'behind': 6986, 'filled': 6819, 'under': 6805, 'little': 6777, 'stop': 6667, 'fire': 6606, 'court': 6573, 'sky': 6381, 'together': 6377, 'into': 6335, 'kite': 6168, 'surfboard': 6166, 'child': 6128, 'background': 6051, 'skis': 6048, 'inside': 5935, 'boat': 5817, 'chair': 5804, 'back': 5795, 'bowl': 5785, 'sheep': 5781, 'bat': 5779, 'big': 5753, 'stands': 5750, 'view': 5699, 'photo': 5681, 'light': 5677, 'bunch': 5666, 'couch': 5618, 'glass': 5586, 'ocean': 5571, 'bird': 5546, 'cell': 5531, 'traffic': 5456, 'shirt': 5425, 'hydrant': 5348, 'mirror': 5334, 'fence': 5305, 'airplane': 5296, 'zebra': 5294, 'teddy': 5273, 'hand': 5260, 'counter': 5243, 'sandwich': 5238, 'orange': 5226, 'women': 5119, 'sidewalk': 5112, 'another': 5092, 'different': 5091, 'wave': 4984, 'floor': 4965, 'plane': 4956, 'lot': 4929, 'giraffes': 4916, 'tall': 4904, 'cars': 4889, 'flowers': 4881, 'stand': 4870, 'tracks': 4867, 'parking': 4865, 'horses': 4852, 'vase': 4805, 'tower': 4751, 'racket': 4662, 'baby': 4652, 'ground': 4610, 'vegetables': 4583, 'zebras': 4573, 'tie': 4531, 'grassy': 4517, 'elephants': 4496, 'being': 4485, 'off': 4437, 'bananas': 4406, 'day': 4366, 'full': 4316, 'middle': 4311, 'along': 4307, 'ready': 4180, 'station': 4167, 'image': 4145, 'dirt': 4129, 'hill': 4112, 'taking': 4079, 'sit': 4048, 'signs': 4034, 'four': 4008, 'bike': 3988, 'driving': 3938, 'stuffed': 3921, 'slope': 3913, 'head': 3869, 'piece': 3812, 'above': 3805, 'long': 3756, 'broccoli': 3747, 'wine': 3740, 'luggage': 3737, 'cows': 3735, 'grazing': 3724, 'across': 3721, 'beside': 3713, 'skiing': 3682, 'snowy': 3611, 'wii': 3561, 'them': 3554, 'skate': 3549, 'hanging': 3531, 'hat': 3528, 'during': 3518, 'refrigerator': 3516, 'glasses': 3496, 'holds': 3477, 'camera': 3466, 'mountain': 3458, 'pink': 3442, 'doing ...

# %%
word_counts.most_common()[::-1]
# Out:
# [('gr$$d', 1),
#  ('etagere', 1),
#  ('brocken', 1),
#  ('attest', 1),
#  ('datsun', 1),
#  ('rejuvenate', 1),
#  ('dweeb', 1),
#  ('caned', 1),
#  ('wimborne', 1),
#  ('tio', 1),
#  ('fashio', 1),
#  ('trackz', 1),
#  ('chiquitta', 1),
#  ('dvr', 1),
#  ('frollicking', 1),
#  ('basilica', 1),
#  ('ensure', 1),
#  ('gnaw', 1),
#  ('tamales', 1),
#  ('leadin', 1),
#  ('townhouse', 1),
#  ('gilt', 1),
#  ('hackney', 1),
#  ('prospect', 1),
#  ('stripping', 1),
#  ('faintly', 1),
#  ('pointers', 1),
#  ('hookups', 1),
#  ('explode', 1),
#  ('phne', 1),
#  ('lately', 1),
#  ('backpocker', 1),
#  ('solemnly', 1),
#  ('hemet', 1),
#  ('cheaply', 1),
#  ('fetta', 1),
#  ('lor', 1),
#  ('motrocycle', 1),
#  ('fridgerater', 1),
#  ('clcktower', 1),
#  ('cobb', 1),
#  ('leanto', 1),
#  ('bluggage', 1),
#  ('freshest', 1),
#  ('saliboat', 1),
#  ('resturaunt', 1),
#  ('burdens', 1),
#  ('3:21', 1),
#  ('parlked', 1),
#  ('hideously', 1),
#  ('resulting', 1),
#  ('urial', 1),
#  ('sesk', 1),
#  ('torbie', 1),
#  ('outstretching', 1),
#  ('faceless', 1),
#  ('tailored', 1),
#  ('strofoam', 1),
#  ('raphael', 1),
#  ('beek', 1),
#  ('campartments', 1),
#  ('swimtrunks', 1),
#  ('rea', 1),
#  ('queuing', 1),
#  ('powdering', 1),
#  ('tripos', 1),
#  ('fieldl', 1),
#  ('clan', 1),
#  ('cadies', 1),
#  ('wage', 1),
#  ('shrugging', 1),
#  ('screeen', 1),
#  ('glam', 1),
#  ('powergliders', 1),
#  ('pottie', 1),
#  ('baseballin', 1),
#  ('lugagge', 1),
#  ('pileed', 1),
#  ('9one', 1),
#  ('peoole', 1),
#  ('chardonnay', 1),
#  ('resaurant', 1),
#  ('receptionists', 1),
#  ('jetairfly', 1),
#  ('teaming', 1),
#  ('forresco', 1),
#  ('amended', 1),
#  ('preset', 1),
#  ('dully', 1),
#  ('forefather', 1),
#  ('retailer', 1),
#  ('spotlessy', 1),
#  ('banaas', 1),
#  ('chamomile', 1),
#  ('preppy', 1),
#  ('trainelectric', 1),
#  ('snowbarder', 1),
#  ('elysees', 1),
#  ('gound', 1),
#  ('223', 1),
#  ('bouitannire', 1),
#  ('julienne', 1),
#  ('skiingo', 1),
#  ('overgrowing', 1),
#  ('forsythia', 1),
#  ('parter', 1),
#  ('marnia', 1),
#  ('songbook', 1),
#  ('airpane', 1),
#  ('eloquent', 1),
#  ('eagled', 1),
#  ('uniforming', 1),
#  ('fres', 1),
#  ('grueling', 1),
#  ('serviceable', 1),
#  ('scisors', 1),
#  ('accomodates', 1),
#  ('roach', 1),
#  ('manipulates', 1),
#  ('ballcap', 1),
#  ('foresty', 1),
#  ('hobbled', 1),
#  ('refreigerator', 1),
#  ('jumpers', 1),
#  ('hlaves', 1),
#  ('cryptic', 1),
#  ('davenport', 1),
#  ('cosplayers', 1),
#  ('excessable', 1),
#  ('flourishing', 1),
#  ('accordingly', 1),
#  ('messezentrum', 1),
#  ('kirschwasser', 1),
#  ('rucksack', 1),
#  ('glimmering', 1),
#  ('blanking', 1),
#  ('hocket', 1),
#  ('gammes', 1),
#  ('33', 1),
#  ('biles', 1),
#  ('trapeze', 1),
#  ('curse', 1),
#  ('downturned', 1),
#  ('thedistance', 1),
#  ('ripens', 1),
#  ('altering', 1),
#  ('berm', 1),
#  ('seting', 1),
#  ('birthing', 1),
#  ('rainier', 1),
#  ('catty', 1),
#  ('farris', 1),
#  ('bleeds', 1),
#  ('broccoliw', 1),
#  ('flambeed', 1),
#  ('smoothi', 1),
#  ('snowpants', 1),
#  ('ktchen', 1),
#  ('forget', 1),
#  ('taxidermist', 1),
#  ('luge', 1),
#  ('wwf', 1),
#  ('replenishing', 1),
#  ('navigated', 1),
#  ('obviously', 1),
#  ('tuks', 1),
#  ('field`', 1),
#  ('hemostats', 1),
#  ('dryed', 1),
#  ('speedo', 1),
#  ('immobile', 1),
#  ('hounded', 1),
#  ('bnp', 1),
#  ('clysdale', 1),
#  ('vacumn', 1),
#  ('employment', 1),
#  ('belltower', 1),
#  ('figured', 1),
#  ('ravaged', 1),
#  ('tanking', 1),
#  ('ashes', 1),
#  ('groundtrain', 1),
#  ('tinkinering', 1),
#  ('c3p0', 1),
#  ('oldl', 1),
#  ('10:00', 1),
#  ('essy', 1),
#  ('regatta', 1),
#  ('slue', 1),
#  ('elfan', 1),
#  ('feminist', 1),
#  ('akureyri', 1),
#  ('sakeboard', 1),
#  ('smithsonian', 1),
#  ('benchq', 1),
#  ('addicott', 1),
#  ('abnormal', 1),
#  ('layinig', 1),
#  ('cookoo', 1),
#  ('24th', 1),
#  ('megabus', 1),
#  ('amusingly', 1),
#  ('greener', 1),
#  ('combos', 1),
#  ('rtbf', 1),
#  ('crave', 1),
#  ('manufactured', 1),
#  ('(lol)', 1),
#  ('careens', 1),
#  ('duit', 1),
#  ('mechanisms', 1),
#  ('allegiance', 1),
#  ('wearng', 1),
#  ('lookd', 1),
#  ('sotp', 1),
#  ('jaguar', 1),
#  ('enbracing', 1),
#  ('buttock', 1),
#  ('ommelette', 1),
#  ('phoneas', 1),
#  ('shrimping', 1),
#  ('slitting', 1),
#  ('leith', 1),
#  ('watermellon', 1),
#  ('complexly', 1),
#  ('enraged', 1),
#  ('spaghettit', 1),
#  ('admit', 1),
#  ('graded', 1),
#  ('pedi', 1),
#  ('wikileaks', 1),
#  ('tinyl', 1),
#  ('sied', 1),
#  ('tennish', 1),
#  ('vied', 1),
#  ('syndrome', 1),
#  ('debit', 1),
#  ('polices', 1),
#  ('youve', 1),
#  ('rdiidng', 1),
#  ('profits', 1),
#  ('jumbotron', 1),
#  ('gayoso', 1),
#  ('hippies', 1),
#  ('sotre', 1),
#  ('downlight', 1),
#  ('rackes', 1),
#  ('asurf', 1),
#  ('apicture', 1),
#  ('filler', 1),
#  ('virgina', 1),
#  ('sickness', 1),
#  ('motored', 1),
#  ('thanking', 1),
#  ('tans', 1),
#  ('topl', 1),
#  ('snickers', 1),
#  ('starry', 1),
#  ('brew', 1),
#  ('expanive', 1),
#  ('emurates', 1),
#  ('magnification', 1),
#  ('fidgeting', 1),
#  ('ridi9ng', 1),
#  ('skrapers', 1),
#  ('itand', 1),
#  ('prater', 1),
#  ('digger', 1),
#  ('twelfth', 1),
#  ('ruff', 1),
#  ('jihwan', 1),
#  ('eich', 1),
#  ('grasscovered', 1),
#  ('karl', 1),
#  ('malfunctioned', 1),
#  ('dragonair', 1),
#  ('spacial', 1),
#  ('smiled', 1),
#  ('worldly', 1),
#  ('teethrbushes', 1),
#  ('condoms', 1),
#  ('butler', 1),
#  ('extinct', 1),
#  ('artillery', 1),
#  ('capistrano', 1),
#  ('undeneath', 1),
#  ('disintegrates', 1),
#  ('sharicmar', 1),
#  ('lyndon', 1),
#  ('strussel', 1),
#  ('hostpital', 1),
#  ('mirror:', 1),
#  ('mae', 1),
#  ('picnickers', 1),
#  ('accumulating', 1),
#  ('sheaths', 1),
#  ('picinic', 1),
#  ('imaginable', 1),
#  ('deocorated', 1),
#  ('lumia', 1),
#  ('discernable', 1),
#  ('innetowne', 1),
#  ('toiilet', 1),
#  ('venting', 1),
#  ('boxcox', 1),
#  ('signson', 1),
#  ('snoopy', 1),
#  ('standihng', 1),
#  ('diaphanous', 1),
#  ('dices', 1),
#  ('nested', 1),
#  ('standingg', 1),
#  ('pakred', 1),
#  ('whitewash', 1),
#  ('giraaffes', 1),
#  ('boywearing', 1),
#  ('roastown', 1),
#  ('[piece', 1),
#  ('podem', 1),
#  ('paradee', 1),
#  ('tthe', 1),
#  ('sicker', 1),
#  ('spacecraft', 1),
#  ('pench', 1),
#  ('bottlec', 1),
#  ('grapple', 1),
#  ('tortia', 1),
#  ('afganistan', 1),
#  ('idolatry', 1),
#  ('volcom', 1),
#  ('rossendalebus', 1),
#  ('transits', 1),
#  ('disclaimer', 1),
#  ('tatoos', 1),
#  ('enlosure', 1),
#  ('ag', 1),
#  ('dandy', 1),
#  ('mulberry', 1),
#  ('distinctly', 1),
#  ('bouttoniere', 1),
#  ('bedsheet', 1),
#  ('cyclone', 1),
#  ('weights', 1),
#  ('flourishes', 1),
#  ('snowless', 1),
#  ('experiments', 1),
#  ('foxy', 1),
#  ('couplee', 1),
#  ('sity', 1),
#  ('disgustingly', 1),
#  ('coleridge', 1),
#  ('breeding', 1),
#  ('pluto', 1),
#  ('powhatan', 1),
#  ('saurkraut', 1),
#  ('tahiti', 1),
#  ('tuckaway', 1),
#  ('jetskiing', 1),
#  ('seati', 1),
#  ('949', 1),
#  ('fei', 1),
#  ('constitute', 1),
#  ('mosaiced', 1),
#  ('rangetop', 1),
#  ('lorna', 1),
#  ('placining', 1),
#  ('fizzy', 1),
#  ('quizzically', 1),
#  ('exteriors', 1),
#  ('rowling', 1),
#  ('enquiries', 1),
#  ('hs', 1),
#  ('shicldren', 1),
#  ('tripple', 1),
#  ('glazer', 1),
#  ('totoro', 1),
#  ('sc', 1),
#  ('medway', 1),
#  ('64', 1),
#  ('misfitting', 1),
#  ('orbach', 1),
#  ('safer', 1),
#  ('serf', 1),
#  ('attachted', 1),
#  ('comers', 1),
#  ('chesterfield', 1),
#  ('villanueva', 1),
#  ('b1', 1),
#  ('mockup', 1),
#  ('showpieces', 1),
#  ('bussess', 1),
#  ('rivier', 1),
#  ('appeals', 1),
#  ('cg', 1),
#  ('finland', 1),
#  ('woodfield', 1),
#  ('teddys', 1),
#  ('pushchair', 1),
#  ('pincer', 1),
#  ('utinsils', 1),
#  ('deadhorse', 1),
#  ('brger', 1),
#  ('annie', 1),
#  ('vegemite', 1),
#  ('poofy', 1),
#  ('journals', 1),
#  ('whips', 1),
#  ('stratches', 1),
#  ('mckee', 1),
#  ('unconnected', 1),
#  ('punks', 1),
#  ('patrion', 1),
#  ('glimpsed', 1),
#  ('scrapped', 1),
#  ('daytona', 1),
#  ('hawaiianese', 1),
#  ('trackwith', 1),
#  ('piicture', 1),
#  ('apark', 1),
#  ('conifer', 1),
#  ('dentists', 1),
#  ('expelling', 1),
#  ('tendril', 1),
#  ('ladnscape', 1),
#  ('tubberware', 1),
#  ('badminto', 1),
#  ('bedae', 1),
#  ('grayscale', 1),
#  ('barell', 1),
#  ('infinitum', 1),
#  ('38th', 1),
#  ('monde', 1),
#  ('antonio', 1),
#  ('emoting', 1),
#  ('updates', 1),
#  ('bellbottoms', 1),
#  ('mozilla', 1),
#  ('onsite', 1),
#  ('undergrowth', 1),
#  ('constrained', 1),
#  ('birthdays', 1),
#  ('conversate', 1),
#  ('cruiseboat', 1),
#  ('4:15pm', 1),
#  ('truck)', 1),
#  ('two:', 1),
#  ('grandchild', 1),
#  ('doghnut', 1),
#  ('curried', 1),
#  ('nightly', 1),
#  ('ganesha', 1),
#  ('$175', 1),
#  ('strew', 1),
#  ('bric', 1),
#  ('unimpeded', 1),
#  ('projectable', 1),
#  ('ruben', 1),
#  ('arr', 1),
#  ('bruit', 1),
#  ('ameican', 1),
#  ('aided', 1),
#  ('b5', 1),
#  ('troubleshoot', 1),
#  ('drivng', 1),
#  ('picutres', 1),
#  ('811', 1),
#  ('donnas', 1),
#  ('orages', 1),
#  ('threshold', 1),
#  ('groomers', 1),
#  ('bumber', 1),
#  ('tenderloin', 1),
#  ('umpired', 1),
#  ('resupplied', 1),
#  ('rainfall', 1),
#  ('pubcap', 1),
#  ('tricked', 1),
#  ('palide', 1),
#  ('gulliver', 1),
#  ('hal', 1),
#  ('leech', 1),
#  ('masses', 1),
#  ('trifled', 1),
#  ('dimming', 1),
#  ('airpline', 1),
#  ('througout', 1),
#  ('applepeople', 1),
#  ('kenmore', 1),
#  ('splotch', 1),
#  ('cisterns', 1),
#  ('$4', 1),
#  ('kohlrabi', 1),
#  ('sweetened', 1),
#  ('sterling', 1),
#  ('nambia', 1),
#  ('f250', 1),
#  ('hails', 1),
#  ('shoaling', 1),
#  ('cite', 1),
#  ('suitecases', 1),
#  ('cloe', 1),
#  ('deflecting', 1),
#  ('binter', 1),
#  ('invite', 1),
#  ('disrupt', 1),
#  ('powderpuff', 1),
#  ('haves', 1),
#  ('hindu', 1),
#  ('thesky', 1),
#  ('frizzebee', 1),
#  ('divisions', 1),
#  ('manly', 1),
#  ('fiend', 1),
#  ('raiser', 1),
#  ('pistil', 1),
#  ('blinding', 1),
#  ('catwalk', 1),
#  ('propperly', 1),
#  ('unassembled', 1),
#  ('gentlemn', 1),
#  ('conspicuously', 1),
#  ('stov', 1),
#  ('bacchanalia', 1),
#  ('galsses', 1),
#  ('numjucks', 1),
#  ('migratory', 1),
#  ('refeigerator', 1),
#  ('huntsville', 1),
#  ('ruwnay', 1),
#  ('concreat', 1),
#  ('pouncing', 1),
#  ('trifold', 1),
#  ('advertsment', 1),
#  ('hydrgian', 1),
#  ('supervised', 1),
#  ('gerbera', 1),
#  ('snowborders', 1),
#  ('198', 1),
#  ('billiards', 1),
#  ('arising', 1),
#  ('37', 1),
#  ('flatcars', 1),
#  ('maidens', 1),
#  ('motorcyclis', 1),
#  ('livingr', 1),
#  ('baskett', 1),
#  ('tigar', 1),
#  ('rents', 1),
#  ('drib', 1),
#  ('nunchuks', 1),
#  ('1:42pm', 1),
#  ('coursing', 1),
#  ('caluiflower', 1),
#  ('dubai', 1),
#  ('mcfly', 1),
#  ('watergun', 1),
#  ('peopleare', 1),
#  ('bke', 1),
#  ('anaimsl', 1),
#  ('chug', 1),
#  ('ivs', 1),
#  ('frisge', 1),
#  ('hampsire', 1),
#  ('hospitable', 1),
#  ('jos', 1),
#  ('connectec', 1),
#  ('overcoming', 1),
#  ('fought', 1),
#  ('giggle', 1),
#  ('jmi', 1),
#  ('1909', 1),
#  ('travelors', 1),
#  ('mannekins', 1),
#  ('2pm', 1),
#  ('myanmar', 1),
#  ('manicans', 1),
#  ('unprepared', 1),
#  ('eatinng', 1),
#  ('dame', 1),
#  ('abat', 1),
#  ('wishbone', 1),
#  ('slefie', 1),
#  ('bernese', 1),
#  ('nand', 1),
#  ('laurels', 1),
#  ('snarls', 1),
#  ('bapp', 1),
#  ('moderators', 1),
#  ('tands', 1),
#  ('vignetted', 1),
#  ('soceer', 1),
#  ('vaccinated', 1),
#  ('unban', 1),
#  ('cesar', 1),
#  ('morose', 1),
#  ('strode', 1),
#  ('riksha', 1),
#  ('woefully', 1),
#  ('giraffesroam', 1),
#  ('hardwoods', 1),
#  ('indivuals', 1),
#  ('streussel', 1),
#  ('glop', 1),
#  ('scientology', 1),
#  ('pachyderm', 1),
#  ('chorale', 1),
#  ('chrysanthemums', 1),
#  ('kited', 1),
#  ('sandisk', 1),
#  ('triplets', 1),
#  ('terminus', 1),
#  ('possibilities', 1),
#  ('timetable', 1),
#  ('lame', 1),
#  ('clickers', 1),
#  ('inhabit', 1),
#  ('tusted', 1),
#  ('meantime', 1),
#  ('sculling', 1),
#  ('skeeter', 1),
#  ('pleasures', 1),
#  ('dour', 1),
#  ('flinging', 1),
#  ('pedestrianised', 1),
#  ('discus', 1),
#  ('painful', 1),
#  ('flied', 1),
#  ('thimbles', 1),
#  ('cues', 1),
#  ('speciality', 1),
#  ('confiserie', 1),
#  ('er', 1),
#  ('pitiful', 1),
#  ('constraining', 1),
#  ('comig', 1),
#  ('panamerican', 1),
#  ('papper', 1),
#  ('atteached', 1),
#  ('sardine', 1),
#  ('traveller', 1),
#  ('skieer', 1),
#  ('palau', 1),
#  ('espn', 1),
#  ('scrubbers', 1),
#  ('doughs', 1),
#  ('cartoonie', 1),
#  ('oer', 1),
#  ('furrow', 1),
#  ('joynt', 1),
#  ('throuhg', 1),
#  ('yello9w', 1),
#  ('zucchinis', 1),
#  ('roamed', 1),
#  ('crestless', 1),
#  ('coinm', 1),
#  ('evolution', 1),
#  ('proposed', 1),
#  ('crosscountry', 1),
#  ('digestif', 1),
#  ('canadas', 1),
#  ('rammed', 1),
#  ('rampant', 1),
#  ('gentlemans', 1),
#  ('seascape', 1),
#  ('menagerie', 1),
#  ('ke', 1),
#  ('beachshore', 1),
#  ('beeds', 1),
#  ('niki', 1),
#  ('folliage', 1),
#  ('conservatory', 1),
#  ('dimmely', 1),
#  ('privliedged', 1),
#  ('bearskin', 1),
#  ('boarwalk', 1),
#  ('skewering', 1),
#  ('linesmans', 1),
#  ('chavez', 1),
#  ('movng', 1),
#  ('dies', 1),
#  ('undersaturated', 1),
#  ('midget', 1),
#  ('wil', 1),
#  ('outstreched', 1),
#  ('89a', 1),
#  ('cth', 1),
#  ('breas', 1),
#  ('equids', 1),
#  ('wanna', 1),
#  ('symmetrical', 1),
#  ('shishkabob', 1),
#  ('retainer', 1),
#  ('alking', 1),
#  ('behold', 1),
#  ('broader', 1),
#  ('obento', 1),
#  ('piggie', 1),
#  ('pentagram', 1),
#  ('binky', 1),
#  ('passegner', 1),
#  ('chex', 1),
#  ('fransisco', 1),
#  ('uickly', 1),
#  ('jagermeister', 1),
#  ('newcastle', 1),
#  ('yspace', 1),
#  ('paymets', 1),
#  ('televisison', 1),
#  ('zebera', 1),
#  ('shirk', 1),
#  ('106', 1),
#  ('lfying', 1),
#  ('mufti', 1),
#  ('kurig', 1),
#  ('verbiage', 1),
#  ('destk', 1),
#  ('officiates', 1),
#  ('marlyn', 1),
#  ('bankers', 1),
#  ('messiah', 1),
#  ('11:18', 1),
#  ('stovetops', 1),
#  ('philips', 1),
#  ('sizzling', 1),
#  ('hodge', 1),
#  ('froyo', 1),
#  ('gridle', 1),
#  ('fleur', 1),
#  ('unprepossessing', 1),
#  ('trials', 1),
#  ('ttied', 1),
#  ('triplane', 1),
#  ('mournfully', 1),
#  ('bucketful', 1),
#  ('mable', 1),
#  ('dealing', 1),
#  ('streed', 1),
#  ('scolds', 1),
#  ('2:05', 1),
#  ('roomed', 1),
#  ('aceite', 1),
#  ('equestrianne', 1),
#  ('hannah', 1),
#  ('basekt', 1),
#  ('bookplates', 1),
#  ('organisation', 1),
#  ('frui', 1),
#  ('ovation', 1),
#  ('littler', 1),
#  ('topcoat', 1),
#  ('floting', 1),
#  ('coner', 1),
#  ('conquer', 1),
#  ('coastals', 1),
#  ('housecat', 1),
#  ('farmerz', 1),
#  ('60016', 1),
#  ('dinousure', 1),
#  ('mcclellan', 1),
#  ('buyer', 1),
#  ('umbrela', 1),
#  ('corgy', 1),
#  ('rakett', 1),
#  ('cameramans', 1),
#  ('barhrrim', 1),
#  ('beeen', 1),
#  ('redish', 1),
#  ('theirir', 1),
#  ('nintindo', 1),
#  ('suns', 1),
#  ('optus', 1),
#  ('kittrn', 1),
#  ('walrus', 1),
#  ('stabilized', 1),
#  ('velvety', 1),
#  ('ect', 1),
#  ('leers', 1),
#  ('keyoard', 1),
#  ('blindsided', 1),
#  ('skatboarder', 1),
#  ('decors', 1),
#  ('cammies', 1),
#  ('ntear', 1),
#  ('restaurannt', 1),
#  ('wrigleys', 1),
#  ('eliminating', 1),
#  ('pinatas', 1),
#  ('redid', 1),
#  ('amplitude', 1),
#  ('bicylce', 1),
#  ('exetended', 1),
#  ('sailsurfing', 1),
#  ('teeny', 1),
#  ('squawking', 1),
#  ('parkinglot', 1),
#  ('atyoung', 1),
#  ('tranes', 1),
#  ('luging', 1),
#  ('disneys', 1),
#  ('postion', 1),
#  ('orpheum', 1),
#  ('crossbeams', 1),
#  ('crazes', 1),
#  ('snowstore', 1),
#  ('pictureisk', 1),
#  ('hairspray', 1),
#  ('bother', 1),
#  ('diploma', 1),
#  ('beadh', 1),
#  ('woods`', 1),
#  ('ohoto', 1),
#  ('barside', 1),
#  ('flamed', 1),
#  ('terry', 1),
#  ('flameless', 1),
#  ('dismay', 1),
#  ('completion', 1),
#  ('cockpits', 1),
#  ('rubberband', 1),
#  ('deadly', 1),
#  ('cour', 1),
#  ('buca', 1),
#  ('fond', 1),
#  ('optimal', 1),
#  ('blancket', 1),
#  ('uncleared', 1),
#  ('neris', 1),
#  ('foofy', 1),
#  ('hamming', 1),
#  ('flowersetting', 1),
#  ('interruption', 1),
#  ('tussling', 1),
#  ('3:32', 1),
#  ('pleope', 1),
#  ('whiskered', 1),
#  ('whits', 1),
#  ('laked', 1),
#  ('fridnds', 1),
#  ('sizzors', 1),
#  ('worldcraft', 1),
#  ('crub', 1),
#  ('showes', 1),
#  ('sizzor', 1),
#  ('aquafina', 1),
#  ('skiislaying', 1),
#  ('archive', 1),
#  ('interception', 1),
#  ('openface', 1),
#  ('statino', 1),
#  ('bronzes', 1),
#  ('latke', 1),
#  ('slinks', 1),
#  ('carasel', 1),
#  ('kalakau', 1),
#  ('monies', 1),
#  ('1:05', 1),
#  ('bleu', 1),
#  ('ahill', 1),
#  ('pllate', 1),
#  ('corraled', 1),
#  ('unvarnished', 1),
#  ('grils', 1),
#  ('idustrial', 1),
#  ('trampled', 1),
#  ('pasteris', 1),
#  ('disturb', 1),
#  ('elks', 1),
#  ('percentage', 1),
#  ('museen', 1),
#  ('cyber', 1),
#  ('plantans', 1),
#  ('hangingother', 1),
#  ('dessed', 1),
#  ('toucing', 1),
#  ('fishhook', 1),
#  ('lumps', 1),
#  ('aster', 1),
#  ('777', 1),
#  ('tyne', 1),
#  ('growths', 1),
#  ('cocered', 1),
#  ('tokens', 1),
#  ('participting', 1),
#  ('dryin', 1),
#  ('stationrailway', 1),
#  ('incomming', 1),
#  ('shrimpa', 1),
#  ('bridegroom', 1),
#  ('openers', 1),
#  ('camelflage', 1),
#  ('taper', 1),
#  ('evelops', 1),
#  ('hon', 1),
#  ('sirty', 1),
#  ('ramada', 1),
#  ('tweaking', 1),
#  ('forting', 1),
#  ('sitares', 1),
#  ('sa', 1),
#  ('chaotic', 1),
#  ('critter', 1),
#  ('fabreeze', 1),
#  ('cabose', 1),
#  ('sandels', 1),
#  ('suped', 1),
#  ('tideline', 1),
#  ('silent', 1),
#  ('nibiling', 1),
#  ('recieves', 1),
#  ('frightful', 1),
#  ('vigan', 1),
#  ('outpost', 1),
#  ('rend', 1),
#  ('fashinoned', 1),
#  ('playinmg', 1),
#  ('sturups', 1),
#  ('scavenging', 1),
#  ('dare', 1),
#  ('paddlers', 1),
#  ('saltine', 1),
#  ('forwar', 1),
#  ('vaulting', 1),
#  ('futile', 1),
#  ('usiing', 1),
#  ('erasers', 1),
#  ('scarp', 1),
#  ('rivet', 1),
#  ('tbone', 1),
#  ('84', 1),
#  ('coffer', 1),
#  ('maned', 1),
#  ('introduce', 1),
#  ('tolworth', 1),
#  ('blooper', 1),
#  ('transdev', 1),
#  ('runwaybeing', 1),
#  ('deeper', 1),
#  ('moisture', 1),
#  ('5070', 1),
#  ('suurfing', 1),
#  ('bonsecours', 1),
#  ('groun', 1),
#  ('rustles', 1),
#  ('dizengoff', 1),
#  ('plied', 1),
#  ('reconditioned', 1),
#  ('deskwith', 1),
#  ('shoring', 1),
#  ('kondike', 1),
#  ('materialize', 1),
#  ('matcihng', 1),
#  ('spritztour', 1),
#  ('ventilators', 1),
#  ('underfoot', 1),
#  ('specialist', 1),
#  ('babybreath', 1),
#  ('peerson', 1),
#  ('silhoutted', 1),
#  ('(motorcycle)', 1),
#  ('brickwork', 1),
#  ('reating', 1),
#  ('raingear', 1),
#  ('middair', 1),
#  ('scotsman', 1),
#  ('hamburber', 1),
#  ('yellowing', 1),
#  ('2:15', 1),
#  ('toured', 1),
#  ('bolders', 1),
#  ('hulk', 1),
#  ('boudoir', 1),
#  ('hillsided', 1),
#  ('readys', 1),
#  ('walton', 1),
#  ('dicussion', 1),
#  ('noshing', 1),
#  ('spry', 1),
#  ('cinematic', 1),
#  ('hurricanes', 1),
#  ('rubbermaid', 1),
#  ('spinx', 1),
#  ('walkman', 1),
#  ('maytag', 1),
#  ('surffing', 1),
#  ('robs', 1),
#  ('middy', 1),
#  ('nab', 1),
#  ('keyhole', 1),
#  ('reign', 1),
#  ('giaffes', 1),
#  ('woden', 1),
#  ('applications', 1),
#  ('tetlling', 1),
#  ('goggle', 1),
#  ('peasant', 1),
#  ('lori', 1),
#  ('camea', 1),
#  ('citit', 1),
#  ('peterbuilt', 1),
#  ('labtops', 1),
#  ...]

# %%
word_counts.most_common()
# Out:
# [('a', 1019785),
#  ('#END#', 616767),
#  ('#START#', 616767),
#  ('on', 224758),
#  ('of', 212689),
#  ('the', 206178),
#  ('in', 191793),
#  ('with', 161216),
#  ('and', 146755),
#  ('is', 102390),
#  ('man', 75957),
#  ('to', 71183),
#  ('sitting', 55190),
#  ('an', 51987),
#  ('two', 50467),
#  ('at', 44506),
#  ('standing', 44297),
#  ('people', 43707),
#  ('are', 42776),
#  ('next', 38867),
#  ('white', 37898),
#  ('woman', 35372),
#  ('street', 31572),
#  ('table', 31444),
#  ('that', 29168),
#  ('holding', 29106),
#  ('large', 25614),
#  ('it', 25608),
#  ('person', 25432),
#  ('some', 25385),
#  ('down', 24038),
#  ('top', 23254),
#  ('group', 22551),
#  ('up', 22425),
#  ('field', 21659),
#  ('small', 20892),
#  ('tennis', 20556),
#  ('near', 20432),
#  ('front', 20342),
#  ('black', 20288),
#  ('his', 20242),
#  ('train', 19464),
#  ('plate', 19183),
#  ('room', 19067),
#  ('riding', 18841),
#  ('dog', 18839),
#  ('red', 18110),
#  ('cat', 17908),
#  ('young', 17804),
#  ('by', 17762),
#  ('water', 17096),
#  ('baseball', 16323),
#  ('has', 15818),
#  ('playing', 15354),
#  ('while', 15278),
#  ('walking', 15182),
#  ('bathroom', 15036),
#  ('sign', 14666),
#  ('blue', 14340),
#  ('kitchen', 13917),
#  ('food', 13851),
#  ('grass', 13559),
#  ('bus', 13372),
#  ('there', 13282),
#  ('green', 13175),
#  ('pizza', 13129),
#  ('side', 13109),
#  ('parked', 13065),
#  ('building', 12980),
#  ('other', 12686),
#  ('bed', 12526),
#  ('looking', 12486),
#  ('snow', 12325),
#  ('beach', 11868),
#  ('ball', 11778),
#  ('couple', 11534),
#  ('three', 11486),
#  ('for', 11431),
#  ('boy', 11281),
#  ('toilet', 11081),
#  ('men', 11032),
#  ('clock', 11008),
#  ('city', 10800),
#  ('road', 10705),
#  ('flying', 10561),
#  ('wearing', 10369),
#  ('out', 10335),
#  ('her', 10333),
#  ('skateboard', 10172),
#  ('player', 10169),
#  ('over', 10064),
#  ('game', 9987),
#  ('several', 9878),
#  ('from', 9739),
#  ('girl', 9729),
#  ('laying', 9728),
#  ('sits', 9694),
#  ('wooden', 9363),
#  ('bench', 9321),
#  ('picture', 9297),
#  ('area', 9138),
#  ('bear', 9111),
#  ('laptop', 9073),
#  ('one', 9039),
#  ('their', 9009),
#  ('through', 8987),
#  ('around', 8835),
#  ('horse', 8797),
#  ('eating', 8759),
#  ('brown', 8756),
#  ('yellow', 8744),
#  ('its', 8720),
#  ('cake', 8686),
#  ('computer', 8576),
#  ('phone', 8536),
#  ('frisbee', 8377),
#  ('sink', 8364),
#  ('board', 8350),
#  ('giraffe', 8228),
#  ('outside', 8156),
#  ('as', 7993),
#  ('living', 7927),
#  ('air', 7887),
#  ('truck', 7795),
#  ('desk', 7726),
#  ('window', 7658),
#  ('motorcycle', 7553),
#  ('close', 7545),
#  ('umbrella', 7444),
#  ('trees', 7394),
#  ('covered', 7392),
#  ('tree', 7384),
#  ('car', 7334),
#  ('open', 7333),
#  ('wall', 7322),
#  ('each', 7271),
#  ('many', 7227),
#  ('park', 7195),
#  ('elephant', 7086),
#  ('old', 7037),
#  ('this', 7028),
#  ('very', 7025),
#  ('behind', 6986),
#  ('filled', 6819),
#  ('under', 6805),
#  ('little', 6777),
#  ('stop', 6667),
#  ('fire', 6606),
#  ('court', 6573),
#  ('sky', 6381),
#  ('together', 6377),
#  ('into', 6335),
#  ('kite', 6168),
#  ('surfboard', 6166),
#  ('child', 6128),
#  ('background', 6051),
#  ('skis', 6048),
#  ('inside', 5935),
#  ('boat', 5817),
#  ('chair', 5804),
#  ('back', 5795),
#  ('bowl', 5785),
#  ('sheep', 5781),
#  ('bat', 5779),
#  ('big', 5753),
#  ('stands', 5750),
#  ('view', 5699),
#  ('photo', 5681),
#  ('light', 5677),
#  ('bunch', 5666),
#  ('couch', 5618),
#  ('glass', 5586),
#  ('ocean', 5571),
#  ('bird', 5546),
#  ('cell', 5531),
#  ('traffic', 5456),
#  ('shirt', 5425),
#  ('hydrant', 5348),
#  ('mirror', 5334),
#  ('fence', 5305),
#  ('airplane', 5296),
#  ('zebra', 5294),
#  ('teddy', 5273),
#  ('hand', 5260),
#  ('counter', 5243),
#  ('sandwich', 5238),
#  ('orange', 5226),
#  ('women', 5119),
#  ('sidewalk', 5112),
#  ('another', 5092),
#  ('different', 5091),
#  ('wave', 4984),
#  ('floor', 4965),
#  ('plane', 4956),
#  ('lot', 4929),
#  ('giraffes', 4916),
#  ('tall', 4904),
#  ('cars', 4889),
#  ('flowers', 4881),
#  ('stand', 4870),
#  ('tracks', 4867),
#  ('parking', 4865),
#  ('horses', 4852),
#  ('vase', 4805),
#  ('tower', 4751),
#  ('racket', 4662),
#  ('baby', 4652),
#  ('ground', 4610),
#  ('vegetables', 4583),
#  ('zebras', 4573),
#  ('tie', 4531),
#  ('grassy', 4517),
#  ('elephants', 4496),
#  ('being', 4485),
#  ('off', 4437),
#  ('bananas', 4406),
#  ('day', 4366),
#  ('full', 4316),
#  ('middle', 4311),
#  ('along', 4307),
#  ('ready', 4180),
#  ('station', 4167),
#  ('image', 4145),
#  ('dirt', 4129),
#  ('hill', 4112),
#  ('taking', 4079),
#  ('sit', 4048),
#  ('signs', 4034),
#  ('four', 4008),
#  ('bike', 3988),
#  ('driving', 3938),
#  ('stuffed', 3921),
#  ('slope', 3913),
#  ('head', 3869),
#  ('piece', 3812),
#  ('above', 3805),
#  ('long', 3756),
#  ('broccoli', 3747),
#  ('wine', 3740),
#  ('luggage', 3737),
#  ('cows', 3735),
#  ('grazing', 3724),
#  ('across', 3721),
#  ('beside', 3713),
#  ('skiing', 3682),
#  ('snowy', 3611),
#  ('wii', 3561),
#  ('them', 3554),
#  ('skate', 3549),
#  ('hanging', 3531),
#  ('hat', 3528),
#  ('during', 3518),
#  ('refrigerator', 3516),
#  ('glasses', 3496),
#  ('holds', 3477),
#  ('camera', 3466),
#  ('mountain', 3458),
#  ('pink', 3442),
#  ('doing', 3430),
#  ('suit', 3404),
#  ('hot', 3401),
#  ('display', 3384),
#  ('fruit', 3369),
#  ('buildings', 3368),
#  ('herd', 3352),
#  ('children', 3326),
#  ('pole', 3318),
#  ('ski', 3312),
#  ('cow', 3302),
#  ('double', 3269),
#  ('empty', 3251),
#  ('corner', 3240),
#  ('umbrellas', 3217),
#  ('going', 3213),
#  ('oven', 3182),
#  ('keyboard', 3180),
#  ('cutting', 3177),
#  ('watching', 3174),
#  ('track', 3168),
#  ('looks', 3167),
#  ('pair', 3162),
#  ('stove', 3151),
#  ('dogs', 3143),
#  ('kites', 3129),
#  ('trick', 3124),
#  ('jumping', 3108),
#  ('smiling', 3096),
#  ('chairs', 3082),
#  ('television', 3060),
#  ('tv', 3047),
#  ('soccer', 3045),
#  ('boats', 3041),
#  ('door', 3032),
#  ('talking', 3012),
#  ('posing', 3010),
#  ('box', 3007),
#  ('traveling', 2982),
#  ('crowd', 2972),
#  ('video', 2961),
#  ('colorful', 2955),
#  ('airport', 2947),
#  ('swinging', 2944),
#  ('topped', 2921),
#  ('animals', 2912),
#  ('surf', 2901),
#  ('birds', 2894),
#  ('various', 2890),
#  ('getting', 2876),
#  ('using', 2874),
#  ('lady', 2828),
#  ('plates', 2821),
#  ('body', 2809),
#  ('set', 2799),
#  ('who', 2797),
#  ('against', 2774),
#  ('hit', 2765),
#  ('all', 2760),
#  ('paper', 2735),
#  ('guy', 2701),
#  ('coffee', 2691),
#  ('brick', 2674),
#  ('wood', 2673),
#  ('carrying', 2658),
#  ('cup', 2653),
#  ('banana', 2645),
#  ('lots', 2644),
#  ('motorcycles', 2642),
#  ('river', 2641),
#  ('cheese', 2603),
#  ('something', 2579),
#  ('bedroom', 2576),
#  ('night', 2576),
#  ('bears', 2569),
#  ('be', 2549),
#  ('waiting', 2542),
#  ('lights', 2539),
#  ('restaurant', 2535),
#  ('house', 2518),
#  ('walk', 2504),
#  ('players', 2502),
#  ('remote', 2477),
#  ('shower', 2470),
#  ('meat', 2464),
#  ('metal', 2461),
#  ('face', 2433),
#  ('skateboarder', 2425),
#  ('bicycle', 2408),
#  ('about', 2403),
#  ('racquet', 2401),
#  ('runway', 2400),
#  ('snowboard', 2398),
#  ('home', 2397),
#  ('items', 2391),
#  ('skier', 2386),
#  ('high', 2379),
#  ('running', 2366),
#  ('decker', 2341),
#  ('surfer', 2334),
#  ('busy', 2333),
#  ('line', 2315),
#  ('jet', 2291),
#  ('ramp', 2291),
#  ('someone', 2275),
#  ('like', 2275),
#  ('hands', 2266),
#  ('passenger', 2262),
#  ('lying', 2258),
#  ('intersection', 2253),
#  ('dressed', 2251),
#  ('male', 2219),
#  ('tray', 2207),
#  ('surfing', 2175),
#  ('mouth', 2152),
#  ('book', 2142),
#  ('suitcase', 2130),
#  ('animal', 2107),
#  ('him', 2103),
#  ('slice', 2103),
#  ('half', 2091),
#  ('shown', 2091),
#  ('cut', 2090),
#  ('he', 2078),
#  ('made', 2077),
#  ('screen', 2069),
#  ('store', 2066),
#  ('preparing', 2066),
#  ('bottle', 2056),
#  ('colored', 2051),
#  ('rides', 2047),
#  ('pulling', 2024),
#  ('gray', 2021),
#  ('bag', 2021),
#  ('bridge', 2012),
#  ('scissors', 2006),
#  ('sleeping', 2004),
#  ('batter', 1997),
#  ('donuts', 1978),
#  ('zoo', 1974),
#  ('way', 1959),
#  ('dark', 1959),
#  ('look', 1952),
#  ('kids', 1948),
#  ('number', 1943),
#  ('enclosure', 1934),
#  ('tub', 1928),
#  ('row', 1908),
#  ('surrounded', 1906),
#  ('sand', 1902),
#  ('knife', 1902),
#  ('between', 1883),
#  ('showing', 1882),
#  ('microwave', 1874),
#  ('play', 1863),
#  ('carrots', 1862),
#  ('toy', 1854),
#  ('jacket', 1853),
#  ('adult', 1852),
#  ('lined', 1841),
#  ('decorated', 1840),
#  ('pile', 1821),
#  ('boys', 1809),
#  ('few', 1808),
#  ('lake', 1806),
#  ('silver', 1803),
#  ('mouse', 1788),
#  ('cabinets', 1784),
#  ('forest', 1771),
#  ('girls', 1771),
#  ('buses', 1768),
#  ('meal', 1765),
#  ('walks', 1756),
#  ('seat', 1755),
#  ('older', 1755),
#  ('bread', 1752),
#  ('skiers', 1747),
#  ('purple', 1728),
#  ('past', 1722),
#  ('furniture', 1715),
#  ('oranges', 1711),
#  ('hair', 1709),
#  ('grey', 1693),
#  ('outdoor', 1691),
#  ('swing', 1683),
#  ('kid', 1662),
#  ('have', 1650),
#  ('waves', 1633),
#  ('cloudy', 1631),
#  ('coming', 1628),
#  ('drink', 1625),
#  ('displayed', 1625),
#  ('attached', 1623),
#  ('throwing', 1608),
#  ('monitor', 1596),
#  ('photograph', 1591),
#  ('fork', 1588),
#  ('chocolate', 1587),
#  ('leaning', 1576),
#  ('onto', 1572),
#  ('making', 1571),
#  ('cats', 1571),
#  ('crossing', 1554),
#  ('can', 1553),
#  ('dining', 1549),
#  ('cross', 1545),
#  ('scene', 1543),
#  ('painted', 1542),
#  ('shelf', 1528),
#  ('lit', 1526),
#  ('stone', 1520),
#  ('rocks', 1520),
#  ('pan', 1519),
#  ('drinking', 1506),
#  ('salad', 1504),
#  ('meter', 1498),
#  ('birthday', 1494),
#  ('seen', 1492),
#  ('hitting', 1490),
#  ('walls', 1488),
#  ('lush', 1486),
#  ('apples', 1481),
#  ('no', 1479),
#  ('office', 1466),
#  ('towards', 1464),
#  ('watch', 1462),
#  ('resting', 1459),
#  ('female', 1458),
#  ('windows', 1455),
#  ('market', 1451),
#  ('public', 1444),
#  ('rain', 1437),
#  ('fruits', 1437),
#  ('apple', 1420),
#  ('dish', 1407),
#  ('sunny', 1406),
#  ('tables', 1404),
#  ('bright', 1399),
#  ('clean', 1394),
#  ('fries', 1385),
#  ('flower', 1384),
#  ('sun', 1383),
#  ('blanket', 1382),
#  ('plastic', 1378),
#  ('leaves', 1368),
#  ('stopped', 1367),
#  ('been', 1364),
#  ('catch', 1362),
#  ('surfboards', 1360),
#  ('edge', 1359),
#  ('books', 1355),
#  ('moving', 1351),
#  ('clear', 1350),
#  ('bikes', 1348),
#  ('setting', 1343),
#  ('teeth', 1342),
#  ('pictures', 1341),
#  ('mountains', 1338),
#  ('beautiful', 1331),
#  ('rail', 1331),
#  ('statue', 1329),
#  ('working', 1316),
#  ('dress', 1311),
#  ('snowboarder', 1309),
#  ('ride', 1303),
#  ('trying', 1300),
#  ('rock', 1300),
#  ('underneath', 1299),
#  ('slices', 1299),
#  ('donut', 1293),
#  ('platform', 1291),
#  ('branch', 1289),
#  ('helmet', 1288),
#  ('yard', 1285),
#  ('uniform', 1280),
#  ('bath', 1270),
#  ('country', 1264),
#  ('time', 1264),
#  ('controller', 1246),
#  ('shot', 1238),
#  ('eat', 1237),
#  ('or', 1230),
#  ('pieces', 1228),
#  ('motor', 1226),
#  ('computers', 1224),
#  ('having', 1219),
#  ('placed', 1216),
#  ('nice', 1213),
#  ('wet', 1210),
#  ('shows', 1209),
#  ('perched', 1208),
#  ('eaten', 1205),
#  ('cellphone', 1196),
#  ('case', 1195),
#  ('skateboarding', 1194),
#  ('cart', 1192),
#  ('basket', 1188),
#  ('shore', 1186),
#  ('pitch', 1185),
#  ('base', 1182),
#  ('passing', 1175),
#  ('cooking', 1167),
#  ('path', 1166),
#  ('sandy', 1162),
#  ('hotel', 1159),
#  ('surface', 1159),
#  ('catcher', 1150),
#  ('pizzas', 1149),
#  ('police', 1144),
#  ('vehicle', 1140),
#  ('modern', 1140),
#  ('dinner', 1138),
#  ('trains', 1137),
#  ('vases', 1136),
#  ('family', 1135),
#  ('others', 1127),
#  ('lap', 1126),
#  ('beer', 1126),
#  ('they', 1125),
#  ('doughnut', 1121),
#  ('laptops', 1120),
#  ('types', 1120),
#  ('boards', 1119),
#  ('brushing', 1117),
#  ('plant', 1117),
#  ('tiled', 1116),
#  ('multiple', 1110),
#  ('just', 1110),
#  ('nintendo', 1098),
#  ('reading', 1098),
#  ('sauce', 1095),
#  ('town', 1093),
#  ('lamp', 1093),
#  ('benches', 1091),
#  ('single', 1089),
#  ('doughnuts', 1086),
#  ('toppings', 1085),
#  ('watches', 1085),
#  ('plants', 1074),
#  ('engine', 1072),
#  ('variety', 1071),
#  ('mounted', 1070),
#  ('post', 1066),
#  ('pitcher', 1064),
#  ('fresh', 1060),
#  ('enjoying', 1057),
#  ('trucks', 1056),
#  ('guys', 1052),
#  ('jump', 1048),
#  ('bowls', 1044),
#  ('graffiti', 1043),
#  ('appliances', 1032),
#  ('distance', 1031),
#  ('passengers', 1031),
#  ('curb', 1031),
#  ('phones', 1028),
#  ('woods', 1026),
#  ('gathered', 1025),
#  ('bathtub', 1025),
#  ('end', 1022),
#  ('pretty', 1020),
#  ('gear', 1019),
#  ('performing', 1017),
#  ('shoes', 1017),
#  ('cute', 1014),
#  ('tarmac', 1014),
#  ('rice', 1012),
#  ('tricks', 1007),
#  ('pen', 1003),
#  ('place', 1001),
#  ('well', 999),
#  ('containing', 997),
#  ('fenced', 996),
#  ('left', 992),
#  ('candles', 990),
#  ('bottles', 981),
#  ('chicken', 976),
#  ('flies', 975),
#  ('carriage', 972),
#  ('shop', 971),
#  ('five', 970),
#  ('pasture', 968),
#  ('toothbrush', 968),
#  ('dirty', 964),
#  ('feeding', 960),
#  ('railroad', 960),
#  ('cattle', 957),
#  ('pot', 956),
#  ('tile', 953),
#  ('take', 950),
#  ('bags', 949),
#  ('concrete', 948),
#  ('match', 946),
#  ('poles', 944),
#  ('below', 943),
#  ('brush', 942),
#  ('right', 938),
#  ('neck', 932),
#  ('school', 931),
#  ('after', 928),
#  ('drinks', 928),
#  ('dock', 928),
#  ('steel', 928),
#  ('control', 920),
#  ('including', 920),
#  ('takes', 918),
#  ('fireplace', 916),
#  ('shaped', 916),
#  ('bar', 915),
#  ('fly', 912),
#  ('pillows', 912),
#  ('striped', 910),
#  ('sofa', 907),
#  ('vintage', 904),
#  ('crowded', 897),
#  ('dry', 893),
#  ('rack', 892),
#  ('pulled', 891),
#  ('flat', 891),
#  ('she', 888),
#  ('sandwiches', 886),
#  ('center', 885),
#  ('fridge', 884),
#  ('polar', 884),
#  ('boxes', 882),
#  ('nearby', 881),
#  ('alone', 879),
#  ('huge', 876),
#  ('catching', 873),
#  ('vehicles', 869),
#  ('planes', 868),
#  ('sinks', 866),
#  ('beds', 865),
#  ('sliced', 863),
#  ('church', 862),
#  ('container', 862),
#  ('reaching', 862),
#  ('equipment', 862),
#  ('skateboards', 855),
#  ('both', 853),
#  ('trunk', 852),
#  ('suitcases', 851),
#  ('feet', 849),
#  ('style', 849),
#  ('bicycles', 845),
#  ('served', 843),
#  ('where', 842),
#  ('arm', 841),
#  ('floating', 839),
#  ('giant', 835),
#  ('plays', 833),
#  ('bushes', 830),
#  ('serve', 830),
#  ('surfers', 827),
#  ('poses', 825),
#  ('asian', 824),
#  ('putting', 822),
#  ('atop', 820),
#  ('towel', 819),
#  ('tomatoes', 817),
#  ('taken', 816),
#  ('smiles', 816),
#  ('sticking', 814),
#  ('away', 814),
#  ('cream', 813),
#  ('legs', 812),
#  ('hay', 811),
#  ('prepares', 810),
#  ('mid', 807),
#  ('dishes', 804),
#  ('clothes', 804),
#  ('potatoes', 803),
#  ('not', 802),
#  ('professional', 801),
#  ('serving', 799),
#  ('staring', 797),
#  ('lays', 797),
#  ('space', 796),
#  ('airplanes', 794),
#  ('wild', 793),
#  ('work', 790),
#  ('commercial', 788),
#  ('spoon', 788),
#  ('foods', 786),
#  ('run', 784),
#  ('pose', 780),
#  ('cabinet', 778),
#  ('which', 775),
#  ('trail', 769),
#  ('breakfast', 767),
#  ('cement', 763),
#  ('show', 763),
#  ('subway', 762),
#  ('painting', 762),
#  ('shorts', 761),
#  ('reflection', 757),
#  ('christmas', 757),
#  ('mother', 754),
#  ('wire', 753),
#  ('stacked', 753),
#  ('square', 753),
#  ('round', 753),
#  ('cooked', 751),
#  ('persons', 749),
#  ('toward', 742),
#  ('lone', 742),
#  ('pool', 741),
#  ('backpack', 740),
#  ('soup', 738),
#  ('same', 738),
#  ('dessert', 733),
#  ('french', 729),
#  ('seated', 727),
#  ('cluttered', 727),
#  ('flag', 726),
#  ('swimming', 725),
#  ('games', 725),
#  ('throw', 723),
#  ('wedding', 721),
#  ('docked', 720),
#  ('highway', 719),
#  ('umpire', 717),
#  ('outdoors', 714),
#  ('pillow', 714),
#  ('swings', 714),
#  ('blender', 712),
#  ('stall', 711),
#  ('go', 708),
#  ('get', 707),
#  ('boarding', 706),
#  ('couches', 705),
#  ('clocks', 704),
#  ('adults', 703),
#  ('sunglasses', 698),
#  ('hotdog', 697),
#  ('business', 695),
#  ('rug', 695),
#  ('assortment', 694),
#  ('garden', 692),
#  ('controllers', 690),
#  ('van', 688),
#  ('drawn', 687),
#  ('drives', 679),
#  ('desktop', 676),
#  ('bun', 673),
#  ('team', 670),
#  ('low', 669),
#  ('among', 669),
#  ('kitten', 669),
#  ('foot', 669),
#  ('doors', 668),
#  ('restroom', 668),
#  ('ice', 666),
#  ('hillside', 664),
#  ('flock', 664),
#  ('ledge', 664),
#  ('facing', 663),
#  ('shelves', 661),
#  ('trash', 661),
#  ('wooded', 660),
#  ('rocky', 659),
#  ('military', 657),
#  ('eyes', 656),
#  ('stainless', 655),
#  ('onions', 653),
#  ('skies', 652),
#  ('jumps', 649),
#  ('fish', 646),
#  ('see', 643),
#  ('desert', 642),
#  ('lawn', 641),
#  ('stairs', 641),
#  ('assorted', 636),
#  ('things', 636),
#  ('cups', 634),
#  ('eats', 633),
#  ('eggs', 632),
#  ('race', 632),
#  ('pointing', 630),
#  ('gate', 628),
#  ('closeup', 628),
#  ('event', 627),
#  ('ceiling', 625),
#  ('someones', 623),
#  ('before', 622),
#  ('clouds', 622),
#  ('monitors', 618),
#  ('steps', 617),
#  ('fashioned', 610),
#  ('coat', 610),
#  ('says', 608),
#  ('picnic', 608),
#  ('glove', 608),
#  ('arranged', 607),
#  ('toddler', 606),
#  ('arms', 604),
#  ('construction', 603),
#  ('land', 602),
#  ('broken', 602),
#  ('curtain', 601),
#  ('party', 601),
#  ('turn', 599),
#  ('rackets', 597),
#  ('snowboarding', 596),
#  ('electronic', 595),
#  ('type', 593),
#  ('friends', 593),
#  ('floors', 592),
#  ('lunch', 590),
#  ('vegetable', 588),
#  ('cage', 587),
#  ('closed', 586),
#  ('pond', 585),
#  ('overlooking', 585),
#  ('landing', 583),
#  ('does', 583),
#  ('tied', 582),
#  ('bottom', 581),
#  ('kneeling', 579),
#  ('narrow', 578),
#  ('roof', 578),
#  ('boarder', 578),
#  ('pots', 577),
#  ('wide', 576),
#  ('new', 575),
#  ('graze', 575),
#  ('tan', 574),
#  ('colors', 573),
#  ('overhead', 571),
#  ('pasta', 569),
#  ('messy', 568),
#  ('kind', 566),
#  ('reads', 566),
#  ('himself', 564),
#  ('sale', 562),
#  ('cakes', 562),
#  ('rider', 561),
#  ('machine', 561),
#  ('fancy', 559),
#  ('skating', 554),
#  ('gold', 552),
#  ('object', 551),
#  ('sides', 551),
#  ('hold', 551),
#  ('trailer', 550),
#  ('appears', 550),
#  ('bite', 547),
#  ('transit', 547),
#  ('cloth', 545),
#  ('features', 544),
#  ('foreground', 543),
#  ('veggies', 543),
#  ('plain', 542),
#  ('suits', 538),
#  ('make', 538),
#  ('towels', 537),
#  ('pie', 537),
#  ('sunset', 536),
#  ('ties', 535),
#  ('walkway', 534),
#  ('leather', 533),
#  ('net', 532),
#  ('pastries', 531),
#  ('carrot', 531),
#  ('photos', 531),
#  ('partially', 530),
#  ('shade', 530),
#  ('pants', 530),
#  ('short', 530),
#  ('mans', 529),
#  ('was', 528),
#  ('action', 527),
#  ('urban', 526),
#  ('sea', 525),
#  ('ear', 523),
#  ('rest', 522),
#  ('toilets', 519),
#  ('antique', 519),
#  ('pepperoni', 518),
#  ('loaded', 518),
#  ('clothing', 518),
#  ('commuter', 517),
#  ('held', 516),
#  ('scooter', 516),
#  ('palm', 515),
#  ('pastry', 513),
#  ('device', 511),
#  ('still', 510),
#  ('ship', 510),
#  ('blurry', 509),
#  ('what', 509),
#  ('toys', 508),
#  ('leash', 507),
#  ('lies', 506),
#  ('baked', 506),
#  ('beneath', 505),
#  ('hole', 505),
#  ('wrapped', 503),
#  ('racing', 502),
#  ('doorway', 501),
#  ('smoke', 500),
#  ('gets', 498),
#  ('houses', 497),
#  ('kinds', 496),
#  ('signal', 496),
#  ('tomato', 495),
#  ('harbor', 494),
#  ('tour', 492),
#  ('pedestrians', 490),
#  ('used', 488),
#  ('chips', 488),
#  ('contains', 488),
#  ('decorative', 488),
#  ('bow', 488),
#  ('structure', 486),
#  ('giving', 484),
#  ('petting', 483),
#  ('fighter', 479),
#  ('lettuce', 479),
#  ('outfit', 478),
#  ('grill', 478),
#  ('pier', 477),
#  ('island', 476),
#  ('includes', 474),
#  ('streets', 473),
#  ('containers', 473),
#  ('sail', 473),
#  ('deck', 472),
#  ('model', 472),
#  ('winter', 472),
#  ('rests', 470),
#  ('garage', 470),
#  ('part', 470),
#  ('railing', 469),
#  ('peppers', 468),
#  ('farm', 468),
#  ('sized', 466),
#  ('beans', 464),
#  ('vanity', 463),
#  ('prepared', 463),
#  ('opened', 462),
#  ('hard', 462),
#  ...]

# %%
word_counts
# Out:
# Counter({'gondola': 16,
#          'teapots': 4,
#          'bookshop': 1,
#          'firetrucks': 20,
#          'skinning': 6,
#          'brushed': 42,
#          'stew': 89,
#          'hamlet': 3,
#          'dictionary': 2,
#          'wielding': 5,
#          'ideal': 3,
#          'suds': 3,
#          'cornucopia': 2,
#          'overreaching': 1,
#          'twinkly': 1,
#          'vinaigrette': 1,
#          'grube': 1,
#          'retail': 59,
#          'trainstop': 1,
#          '[sic]': 1,
#          'entrancing': 5,
#          'fields': 80,
#          'bertuccis': 1,
#          'aveeno': 1,
#          'cutlets': 1,
#          'sagebrush': 3,
#          'broiler': 5,
#          'perishing': 1,
#          'sheeps': 55,
#          'sruf': 1,
#          'fairfax': 1,
#          'weighing': 4,
#          'lunges': 40,
#          'apart': 113,
#          'bridesmaids': 1,
#          'watched': 95,
#          'wolverine': 4,
#          'dyed': 24,
#          'barthroom': 1,
#          '6:18': 1,
#          'susans': 1,
#          'ahouse': 1,
#          'standalone': 4,
#          'woking': 1,
#          'lidless': 3,
#          'slope': 3913,
#          'automated': 15,
#          'earliest': 2,
#          'turning': 263,
#          'fowls': 2,
#          'passenger': 2262,
#          'openfaced': 1,
#          'stree': 6,
#          'brocolli': 79,
#          'latches': 1,
#          'scrambles': 5,
#          'prism': 1,
#          'volunteer': 8,
#          'pepperoncini': 1,
#          'g': 16,
#          'pairs': 180,
#          'bunless': 1,
#          'treks': 8,
#          'travelingm': 1,
#          'instructors': 3,
#          'vats': 3,
#          'button': 152,
#          'hydrant': 5348,
#          'utmost': 1,
#          'bangs': 14,
#          '1014': 1,
#          'bide': 1,
#          'mechanics': 9,
#          'nyc': 5,
#          'stilt': 1,
#          'tuktuk': 1,
#          'platfrom': 1,
#          'cave': 48,
#          'areanear': 1,
#          'talkes': 1,
#          'fireball': 1,
#          'claimy': 1,
#          'picachu': 1,
#          'candy': 213,
#          'girders': 4,
#          'indonesian': 1,
#          'olympians': 2,
#          'segull': 1,
#          'toppling': 1,
#          'deceptions': 1,
#          'severed': 5,
#          '54': 12,
#          'dell': 25,
#          'fence': 5305,
#          'expansive': 14,
#          'tv': 3047,
#          'keepsakes': 1,
#          'shuny': 1,
#          'taptops': 1,
#          'crown': 71,
#          'racehorse': 5,
#          'land': 602,
#          'advanced': 13,
#          'parental': 1,
#          'leis': 3,
#          'tourer': 1,
#          'snowball': 7,
#          'arugala': 1,
#          'lowing': 2,
#          'packed': 345,
#          'supposed': 6,
#          'melting': 29,
#          'telltale': 1,
#          'obsticle': 1,
#          'outfielders': 1,
#          'illuminate': 15,
#          'decor': 213,
#          'quadruple': 2,
#          'tricolored': 1,
#          'cherub': 5,
#          'nostalgic': 6,
#          'costa': 3,
#          'lighted': 167,
#          'seoul': 1,
#          'porcelain': 112,
#          'fieled': 1,
#          'vittel': 1,
#          'codling': 1,
#          'airplanes': 794,
#          'breezy': 1,
#          'stirfry': 5,
#          'illustration': 20,
#          'phallic': 2,
#          'require': 4,
#          'brides': 9,
#          'emu': 5,
#          'economic': 2,
#          'alighted': 1,
#          'superimposed': 11,
#          'snooping': 4,
#          'stands': 5750,
#          'soft': 148,
#          'sidedown': 1,
#          'expanive': 1,
#          'turboprop': 3,
#          'kithcen': 1,
#          'shire': 2,
#          'spotlights': 3,
#          'scenes': 27,
#          'sighting': 3,
#          'lushly': 5,
#          'norway': 1,
#          'comforters': 9,
#          'des': 5,
#          'sapphire': 1,
#          'folders': 11,
#          'urinel': 1,
#          'printing': 8,
#          'alcoholic': 30,
#          'structure': 486,
#          'yonng': 1,
#          'demonstrated': 1,
#          'inu': 1,
#          'lifevest': 2,
#          'coupon': 1,
#          'bookend': 1,
#          'heliocopter': 1,
#          'people': 43707,
#          'beign': 2,
#          'cresting': 16,
#          'spans': 7,
#          'resiting': 1,
#          'sacred': 1,
#          'snowshoes': 15,
#          'posh': 10,
#          'prior': 10,
#          'pantries': 1,
#          'simpsons': 8,
#          'disappointment': 1,
#          'materials': 86,
#          'blows': 65,
#          'unwelcoming': 1,
#          'latte': 10,
#          'period': 19,
#          'dials': 13,
#          'rats': 1,
#          'dalmation': 12,
#          'nation': 2,
#          'hillside': 664,
#          'tide': 69,
#          'ducky': 14,
#          'taller': 42,
#          'enrapturing': 2,
#          'racquete': 1,
#          'oct': 1,
#          'rolly': 1,
#          'more': 247,
#          'wining': 1,
#          '8:05': 1,
#          'mug': 430,
#          'rain': 1437,
#          'artificially': 1,
#          'ironing': 37,
#          'zookeeper': 9,
#          'intended': 10,
#          'tilted': 61,
#          'railed': 6,
#          'coalition': 3,
#          'polar': 884,
#          'familys': 4,
#          'opposie': 1,
#          'sunburnt': 1,
#          'edited': 12,
#          'suiit': 1,
#          'interacts': 10,
#          'seemingly': 28,
#          'composition': 4,
#          'boulevard': 25,
#          'hen': 8,
#          'positive': 1,
#          'nuggest': 1,
#          'screensaver': 8,
#          'smirky': 1,
#          'returned': 17,
#          'merged': 3,
#          'mexican': 75,
#          'shoe': 372,
#          'bassinet': 6,
#          'stile': 1,
#          'sandich': 3,
#          'songbirds': 1,
#          'traveling': 2982,
#          'defies': 1,
#          'exte': 1,
#          'besd': 1,
#          'snyone': 1,
#          'snow': 12325,
#          'cubicles': 10,
#          'xxx': 1,
#          'poked': 6,
#          'hockey': 51,
#          'business': 695,
#          'risking': 1,
#          'roma': 1,
#          'hatchback': 8,
#          'sliding': 404,
#          'antlers': 9,
#          'descends': 16,
#          'gay': 29,
#          'spoke': 6,
#          'bonnet': 8,
#          'cambodian': 1,
#          'ketcheup': 1,
#          'sturcture': 1,
#          'slammed': 3,
#          'verying': 1,
#          '52': 1,
#          'ae': 4,
#          'olden': 4,
#          'be': 2549,
#          'rat': 28,
#          'wet': 1210,
#          'skylight': 25,
#          'bengal': 1,
#          'horn': 69,
#          'papered': 10,
#          'ham': 275,
#          'disposal': 7,
#          'ballfield': 3,
#          'macaron': 1,
#          'ignore': 4,
#          'baseboard': 1,
#          'bricks': 91,
#          'instruments': 81,
#          'fear': 4,
#          'adjusts': 55,
#          'frui': 1,
#          'chopstick': 2,
#          'wouldl': 1,
#          'hunkered': 3,
#          'hoof': 11,
#          'transform': 1,
#          'clippers': 10,
#          'captivating': 1,
#          'erected': 18,
#          'gil': 1,
#          'modernly': 3,
#          'pew': 6,
#          'airfield': 81,
#          'girraffe': 7,
#          'invades': 1,
#          'hawks': 6,
#          'repellent': 2,
#          '#END#': 616767,
#          'teton': 1,
#          'hurries': 1,
#          'cycles': 97,
#          'discharge': 2,
#          'leashes': 44,
#          'amlost': 1,
#          'stringer': 1,
#          'miicrosoft': 1,
#          'turnover': 1,
#          'meter': 1498,
#          'staining': 4,
#          'thinness': 2,
#          'nice': 1213,
#          'failed': 3,
#          'eclosed': 1,
#          'booties': 10,
#          'a350': 1,
#          'simmers': 1,
#          'gamer': 7,
#          'sedans': 1,
#          'teating': 1,
#          'stopsign': 2,
#          'glares': 12,
#          'aim': 9,
#          'skate': 3549,
#          'bergs': 1,
#          'amaryllis': 2,
#          'endless': 3,
#          'uncomfortable': 9,
#          'roomy': 5,
#          'midway': 5,
#          'hotdog': 697,
#          'calves': 54,
#          'kicks': 68,
#          'beiges': 1,
#          'sent': 2,
#          'shoves': 2,
#          'rescue': 40,
#          'official': 52,
#          'brethren': 1,
#          'vegs': 1,
#          'raddishes': 2,
#          'hunched': 49,
#          'competitor': 27,
#          'coon': 2,
#          'inlayed': 1,
#          'musk': 1,
#          'status': 5,
#          'infrastructure': 2,
#          'yaks': 15,
#          'alligators': 4,
#          'marzipan': 2,
#          'east': 32,
#          'marchers': 1,
#          'shelfing': 2,
#          'foors': 1,
#          'lunging': 44,
#          'waterskis': 3,
#          'considers': 1,
#          'sheepdog': 16,
#          'toiletnext': 1,
#          'dexter': 1,
#          'aprons': 33,
#          'upon': 211,
#          'crates': 122,
#          'unmatched': 3,
#          'veriety': 2,
#          'boxcars': 11,
#          'kitchenwith': 1,
#          'served': 843,
#          'brackets': 5,
#          'palette': 3,
#          'limit': 77,
#          'hull': 8,
#          'plenty': 96,
#          'kind': 566,
#          'skiboard': 5,
#          'lagoon': 21,
#          'bomber': 26,
#          '2+': 1,
#          'joseph': 1,
#          'smashing': 3,
#          'measurement': 2,
#          'cairn': 1,
#          'kitteh': 4,
#          'looses': 1,
#          'microwave': 1874,
#          'alternate': 1,
#          'motorcyclist': 211,
#          'creepy': 56,
#          'vendors': 73,
#          'sailboats': 166,
#          'lord': 2,
#          'submerging': 1,
#          'teasing': 1,
#          'slender': 27,
#          'serrated': 5,
#          'pharmacy': 6,
#          'green': 13175,
#          'directories': 1,
#          'unawares': 1,
#          'weatherman': 1,
#          'hefty': 3,
#          'appointed': 22,
#          'janes': 1,
#          'lowering': 18,
#          'groceries': 45,
#          'giraffestanding': 2,
#          'claw': 50,
#          'storybooks': 1,
#          '381': 2,
#          'doyers': 2,
#          'audio': 22,
#          'grub': 2,
#          'shoppe': 5,
#          'defensively': 1,
#          '2009': 5,
#          'loft': 48,
#          'warped': 9,
#          'kiwifruit': 1,
#          'kerns': 1,
#          'carrall': 1,
#          'profoundly': 1,
#          'giraffew': 1,
#          'stretched': 121,
#          'terminals': 14,
#          'trivets': 1,
#          'domo': 2,
#          'thedoor': 1,
#          'merchants': 7,
#          'corful': 1,
#          'croissant': 47,
#          'kebab': 2,
#          'footstool': 9,
#          'matted': 3,
#          'bronzed': 1,
#          'cell': 5531,
#          'bursking': 1,
#          'duble': 1,
#          'brwon': 1,
#          'parasailers': 19,
#          'portions': 21,
#          'ethiopian': 2,
#          'impaled': 4,
#          'escapologist': 1,
#          'abutment': 1,
#          'fliers': 14,
#          'umberlla': 3,
#          'troops': 1,
#          'soldiers': 150,
#          'peeson': 1,
#          'skip': 1,
#          'desser': 1,
#          'toll': 27,
#          'unready': 1,
#          'sudsy': 4,
#          'snooze': 4,
#          'deocrated': 1,
#          'wondow': 2,
#          'bloom': 29,
#          'movement': 20,
#          'archeologists': 1,
#          'trips': 4,
#          'banannas': 5,
#          'preprepared': 1,
#          'bumps': 10,
#          'cabins': 9,
#          '34th': 11,
#          'copying': 2,
#          'ripe': 445,
#          'doo': 6,
#          'windbreaker': 3,
#          'foreheads': 7,
#          'plus': 23,
#          'hollandaise': 4,
#          'ide': 1,
#          'barometer': 1,
#          'pecks': 12,
#          'gato': 1,
#          'rumps': 1,
#          'railhouse': 1,
#          'lush': 1486,
#          'union': 35,
#          'boxcar': 9,
#          '15': 6,
#          'runing': 2,
#          'sculpture': 347,
#          'rider': 561,
#          'handome': 1,
#          'weenies': 5,
#          'conferring': 2,
#          'victoria': 10,
#          'hardcourt': 1,
#          'catamaran': 7,
#          'biscotti': 1,
#          'decidantly': 1,
#          'skydiving': 1,
#          'nap': 171,
#          'intercity': 1,
#          'utensil': 50,
#          'bluejacket': 1,
#          'metroline': 1,
#          'worship': 3,
#          'morotcycle': 1,
#          'horseradish': 1,
#          'former': 10,
#          'etch': 1,
#          'wineglasses': 19,
#          'finch': 8,
#          'etc': 26,
#          'surgically': 1,
#          'pleased': 10,
#          'upstage': 1,
#          'cumbers': 1,
#          'parkeda': 1,
#          'exclamation': 4,
#          'weeks': 2,
#          'caller': 1,
#          'oxen': 49,
#          'definitely': 10,
#          'radiator': 55,
#          'snowbording': 1,
#          'rodents': 2,
#          'catsup': 12,
#          'sailboarders': 1,
#          'sande': 1,
#          'trappist': 1,
#          'ornately': 29,
#          'withs': 3,
#          'iin': 5,
#          'oof': 1,
#          'travcks': 1,
#          'destop': 1,
#          'dirtbikes': 4,
#          'hoofed': 2,
#          'aggression': 1,
#          'captions': 3,
#          'golds': 3,
#          'trailor': 3,
#          'unfired': 1,
#          'jpg': 1,
#          'bnse': 2,
#          'gut': 1,
#          'tailors': 1,
#          'ventilation': 6,
#          'inspirion': 1,
#          'voyeuristic': 1,
#          'manin': 2,
#          'pawing': 28,
#          'sneakers': 133,
#          'humps': 4,
#          'miserably': 1,
#          '3:18': 1,
#          'turnups': 1,
#          'shishkabobs': 2,
#          'sexily': 1,
#          'cartoons': 11,
#          'zany': 1,
#          'cheffin': 2,
#          'barbie': 12,
#          'crickets': 2,
#          'medical': 83,
#          'month': 4,
#          'zoos': 2,
#          'raindrops': 2,
#          'produces': 3,
#          'measured': 6,
#          'songbird': 4,
#          'chiild': 1,
#          'fittings': 3,
#          'po': 1,
#          'peene': 1,
#          'charlie': 5,
#          'snaps': 7,
#          'cabbages': 11,
#          'distinctive': 7,
#          'entertainment': 219,
#          'thrill': 2,
#          'wildnerness': 2,
#          'squiggly': 2,
#          'exercising': 16,
#          '9:34': 1,
#          '7:45': 1,
#          'trigger': 1,
#          'sheets': 440,
#          'touratech': 1,
#          'benchs': 5,
#          'daugher': 2,
#          'olympic': 56,
#          'dissecting': 1,
#          'm': 73,
#          'freckles': 2,
#          'airier': 1,
#          'hoscb': 1,
#          'gauze': 7,
#          'gross': 14,
#          'traipsing': 2,
#          'gingersnaps': 1,
#          'taiwan': 1,
#          'couple': 11534,
#          'woodpile': 2,
#          'deliteful': 1,
#          'bugg': 1,
#          'digs': 9,
#          'palce': 1,
#          'refueled': 3,
#          'freesby': 4,
#          'reflections': 25,
#          'signify': 1,
#          'steamy': 4,
#          'sheriff': 6,
#          'dismount': 2,
#          'charaters': 1,
#          'llamas': 12,
#          'hyper': 1,
#          'iv': 8,
#          'ovoid': 1,
#          'blackbear': 1,
#          'nightstand': 113,
#          'porkchop': 1,
#          'detracts': 1,
#          'capped': 111,
#          'pierce': 1,
#          'wristwatch': 3,
#          'incomplete': 6,
#          'dispense': 1,
#          'magnets': 215,
#          'manufactures': 2,
#          'wherein': 2,
#          'neat': 212,
#          'protect': 30,
#          'navigating': 36,
#          'promotion': 1,
#          'cross': 1545,
#          'matteress': 1,
#          'cats': 1571,
#          'bigtop': 1,
#          'armful': 1,
#          'blackshirt': 1,
#          'thomas': 42,
#          'presents': 75,
#          '11:43': 1,
#          'year': 49,
#          'freesbie': 1,
#          'airbase': 1,
#          'frinds': 1,
#          'kalakaua': 1,
#          'platformin': 1,
#          'congested': 17,
#          'news': 89,
#          'knocked': 60,
#          'tents': 142,
#          'buzzards': 4,
#          'prospective': 1,
#          'planetary': 3,
#          'blackbird': 5,
#          'headpieces': 1,
#          'cooper': 2,
#          'fiesta': 1,
#          'basebal': 6,
#          'iridescent': 3,
#          'neoclassical': 3,
#          'enormous': 56,
#          'potty': 29,
#          'sitting': 55190,
#          'cooler': 91,
#          'pitched': 105,
#          'skid': 1,
#          '1:20': 2,
#          'carless': 1,
#          'propellered': 1,
#          'photgraph': 1,
#          'truffles': 2,
#          'kitesurfing': 13,
#          'upheld': 3,
#          'fueled': 6,
#          'gossops': 1,
#          'distnace': 1,
#          'bench': 9321,
#          'beale': 2,
#          'spoons': 157,
#          'birds': 2894,
#          'plain': 542,
#          'skateboarer': 1,
#          'cobble': 29,
#          'stupidest': 1,
#          'bursts': 2,
#          'kayak': 82,
#          'crumple': 1,
#          'women': 5119,
#          'encourages': 2,
#          'peole': 4,
#          'motherly': 1,
#          'terrified': 1,
#          'next': 38867,
#          'tail': 331,
#          'evicted': 1,
#          'rate': 4,
#          'grizzle': 7,
#          'security': 64,
#          'exotic': 60,
#          'cascade': 4,
#          'burger': 246,
#          'kickstand': 11,
#          'backgruond': 1,
#          'reaction': 1,
#          'nicey': 1,
#          'clots': 1,
#          'mu': 1,
#          'vegetales': 1,
#          'trivia': 1,
#          '$6500': 1,
#          'wearign': 3,
#          'flaky': 4,
#          'whie': 1,
#          'email': 7,
#          'thistle': 3,
#          'laniard': 1,
#          'waiting': 2542,
#          'backgropund': 2,
#          'reveals': 27,
#          'flaming': 11,
#          'rambunctious': 1,
#          'segment': 5,
#          'eurpean': 1,
#          'thinking': 16,
#          'skinny': 113,
#          'foxy': 1,
#          'whichn': 1,
#          'meaty': 13,
#          '3400': 1,
#          'and=f': 1,
#          'kitesurfs': 1,
#          'appeal': 3,
#          'chanced': 1,
#          'cupp': 1,
#          'balone': 1,
#          'cursive': 5,
#          'dispenses': 3,
#          'dresswear': 1,
#          'sneaker': 35,
#          'peep': 7,
#          'wishes': 10,
#          'infielders': 1,
#          'handset': 10,
#          'chart': 9,
#          'reciept': 1,
#          'roadways': 1,
#          'barbecue': 75,
#          'eventually': 6,
#          'pond': 585,
#          'wiggly': 3,
#          'forklifts': 1,
#          'grasping': 19,
#          'birdge': 2,
#          'glazing': 7,
#          'streetin': 2,
#          'novels': 5,
#          'vast': 91,
#          'beansprout': 1,
#          'expectantly': 5,
#          'sewing': 90,
#          'eggbeater': 2,
#          'taxied': 2,
#          'polka': 144,
#          'prying': 1,
#          'traing': 2,
#          'resigned': 1,
#          'beast': 8,
#          'plumage': 2,
#          'vibrating': 2,
#          'stopwatch': 3,
#          'skatebaords': 1,
#          'tranit': 1,
#          'gentlemens': 1,
#          'casting': 41,
#          'stomping': 2,
#          'graffitid': 7,
#          'reclining': 56,
#          '666': 1,
#          'baeach': 1,
#          'weekend': 4,
#          'pricing': 3,
#          'folded': 224,
#          'chillin': 11,
#          'mart': 1,
#          'cahir': 1,
#          'cries': 3,
#          'fawked': 1,
#          'mauve': 7,
#          'devise': 3,
#          'hyatt': 2,
#          'avoiding': 11,
#          'though': 85,
#          'dandelions': 7,
#          'adjust': 20,
#          'transmits': 1,
#          'hyrdo': 1,
#          'haysurrounded': 1,
#          'pilled': 7,
#          'midwestern': 3,
#          'precious': 1,
#          '$6999': 1,
#          'computrs': 1,
#          'atari': 1,
#          'injuring': 1,
#          'lis': 1,
#          'perforated': 1,
#          'paying': 40,
#          'begging': 20,
#          'cereal': 179,
#          'seattle': 14,
#          'have': 1650,
#          'journey': 10,
#          'baths': 2,
#          'unboarding': 1,
#          'panamerican': 1,
#          'eggy': 1,
#          'shoer': 1,
#          'positions': 52,
#          'wy': 1,
#          'eyebrow': 1,
#          'anteaters': 1,
#          'huddles': 3,
#          '1802': 1,
#          'coordinating': 11,
#          'wiyh': 1,
#          'boomerang': 2,
#          'holly': 8,
#          'software': 4,
#          'receiving': 32,
#          'sweetend': 1,
#          'gadzooks': 1,
#          'fatsos': 3,
#          'lighten': 1,
#          'tasted': 3,
#          '35': 10,
#          'twig': 39,
#          'skii': 15,
#          'approaches': 170,
#          'eleven': 26,
#          'footbridge': 5,
#          'eyecatching': 1,
#          'seuvignon': 1,
#          'twp': 16,
#          'carlisle': 1,
#          'most': 131,
#          'massage': 4,
#          'softcover': 1,
#          'copies': 3,
#          'fences': 50,
#          'specific': 8,
#          'greases': 1,
#          'chile': 2,
#          'movie': 114,
#          'overbaked': 1,
#          'handrails': 10,
#          'exercises': 8,
#          'smushing': 1,
#          'furred': 6,
#          'rig': 40,
#          'roost': 3,
#          'olds': 4,
#          'strength': 5,
#          'railcar': 1,
#          'chacarita': 1,
#          'elsewhere': 3,
#          'columbia': 3,
#          'trainer': 70,
#          'veins': 1,
#          'gentle': 43,
#          'seems': 249,
#          'blurs': 7,
#          'wandering': 92,
#          'caucasian': 14,
#          'cocks': 4,
#          'calk': 1,
#          'clumps': 8,
#          'shrubs': 127,
#          'backends': 1,
#          'snowcapped': 5,
#          'tubing': 5,
#          'roberts': 1,
#          'which': 775,
#          'siamese': 74,
#          'bullpen': 9,
#          'rding': 2,
#          'sees': 18,
#          'eight': 122,
#          'sherman': 3,
#          'containg': 2,
#          'efron': 1,
#          'shear': 7,
#          'colas': 1,
#          'forks': 160,
#          'copula': 1,
#          'mariner': 1,
#          'anyone': 16,
#          'tot': 18,
#          'would': 51,
#          'sleding': 1,
#          'transept': 1,
#          'intersections': 9,
#          'trailer': 550,
#          'tongues': 5,
#          'hitters': 1,
#          'south': 37,
#          'pretty': 1020,
#          'fisher': 3,
#          'disco': 8,
#          'topic': 2,
#          'aball': 1,
#          'airstrips': 1,
#          'hangliding': 1,
#          'absolutley': 1,
#          'sloppy': 20,
#          'spaulding': 1,
#          'headstone': 4,
#          'parody': 1,
#          'execute': 2,
#          'accesories': 1,
#          'room': 19067,
#          'cubical': 9,
#          '1900s': 5,
#          'shorted': 1,
#          'backgournd': 1,
#          'mandarins': 3,
#          'croisants': 1,
#          'confusedly': 2,
#          'goats': 382,
#          'greenish': 14,
#          'greeted': 4,
#          'association': 3,
#          'zoo': 1974,
#          'hog': 19,
#          'rustc': 1,
#          'stealthily': 1,
#          'phissing': 1,
#          'strangled': 1,
#          'sands': 19,
#          'underwater': 25,
#          'hin': 2,
#          'tred': 1,
#          'nacks': 6,
#          'subjects': 3,
#          'awakens': 1,
#          'dodge': 15,
#          'suitcase': 2130,
#          'souvenir': 3,
#          'prject': 1,
#          'ac': 4,
#          'sunning': 8,
#          'tighty': 2,
#          'balogna': 1,
#          'giraffee': 13,
#          'kripsy': 2,
#          'untidy': 21,
#          'forklift': 20,
#          'enthusiasm': 4,
#          'gestures': 36,
#          'burried': 4,
#          'sherpard': 1,
#          'walker': 27,
#          'supplies': 358,
#          'towers': 124,
#          'laugar': 1,
#          'stars': 69,
#          'roade': 1,
#          'sosthing': 1,
#          'chalk': 32,
#          'i': 442,
#          '1040s': 1,
#          'those': 90,
#          'naming': 2,
#          'aeriel': 1,
#          'baboons': 1,
#          'bouncing': 53,
#          'workstations': 1,
#          'park': 7195,
#          'indonesia': 1,
#          'suggestions': 1,
#          'rip': 7,
#          'floated': 1,
#          'peices': 3,
#          'jammed': 11,
#          'lolly': 2,
#          'widescreen': 7,
#          'suckles': 5,
#          'squash': 83,
#          'missles': 3,
#          'mortor': 1,
#          'e23': 1,
#          'aloud': 2,
#          'fisbeegame': 1,
#          'cose': 1,
#          'accepting': 6,
#          'entire': 42,
#          'dammed': 1,
#          'cloves': 5,
#          'apparel': 20,
#          'standind': 3,
#          'nside': 1,
#          'trudging': 4,
#          'ciy': 2,
#          'mahouts': 2,
#          'no2': 1,
#          ...})

# %%
vocab  = ['#UNK#', '#START#', '#END#']
vocab += [k for k, v in word_counts.items() if v >= 5]
n_tokens = len(vocab)

assert 10000 <= n_tokens <= 10500

word_to_index = {w: i for i, w in enumerate(vocab)}

# %%
PAD_ix = -1
UNK_ix = vocab.index('#UNK#')

#good old as_matrix for the third time
def as_matrix(sequences,max_len=None):
    max_len = max_len or max(map(len,sequences))
    
    matrix = np.zeros((len(sequences),max_len),dtype='int32')+PAD_ix
    for i,seq in enumerate(sequences):
        row_ix = [word_to_index.get(word,UNK_ix) for word in seq[:max_len]]
        matrix[i,:len(row_ix)] = row_ix
    
    return matrix

# %%
#try it out on several descriptions of a random image
as_matrix(captions[1337])
# Out:
# array([[ 7000, 10118,  7517,  5814,  1037, 10134,  5885,  2433,  1671,
#          2339,  9092,  4953,   131,    -1,    -1],
#        [ 7000,  1671,  2339,  8701,  5213,   950,  4953,  9092,  3010,
#          2606,  5885,   131,    -1,    -1,    -1],
#        [ 7000,  2167,  5814,  1037, 10134,  5885,  2433,  1671,  8553,
#          1296,   284,  1113,  4468,  9383,   131],
#        [ 7000,  2167,  7328,  4893,  1289,  5271,  2167,  7328,  3517,
#           131,    -1,    -1,    -1,    -1,    -1],
#        [ 7000, 10118,  7517,  5814,  1037, 10134,  5885,  2433,  1671,
#          2339,   284,  1113,  5325,   131,    -1]], dtype=int32)

# %% [markdown]
# ### Mah Neural Network

# %%
# network shapes. 
CNN_FEATURE_SIZE = img_codes.shape[1]
EMBED_SIZE = 128 #pls change me if u want
LSTM_UNITS = 200 #pls change me if u want

# %%
import theano
import theano.tensor as T
# Out:
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release.  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5105)

# %%
# Input Variable
sentences = T.imatrix()# [batch_size x time] of word ids
image_vectors = T.matrix() # [batch size x unit] of CNN image features
sentence_mask = T.neq(sentences,PAD_ix)

# %%
import lasagne
from lasagne.layers import *

# %%
#network inputs
l_words = InputLayer((None,None),sentences )
l_mask = InputLayer((None,None),sentence_mask )

#embeddings for words 
#<apply word embedding. use EMBED_SIZE>

l_word_embeddings = EmbeddingLayer(l_words,n_tokens,EMBED_SIZE)

#cudos for using some pre-trained embedding :)

# %%
l_word_embeddings.output_shape
CNN_FEATURE_SIZE
# Out:
# 1000

# %%
# input layer for image features
l_image_features = InputLayer((None,CNN_FEATURE_SIZE),image_vectors )

#convert 1000 image features from googlenet to whatever LSTM_UNITS you have set
#it's also a good idea to add some dropout here and there

#<<convert l_image features to a shape equal to rnn hidden state. Also play with dropout/noize>

l_image_features_small = DenseLayer(l_image_features,LSTM_UNITS)

assert l_image_features_small.output_shape == (None,LSTM_UNITS)

# %%
# Concatinate image features and word embedings in one sequence 
decoder = LSTMLayer(l_word_embeddings,LSTM_UNITS,cell_init=l_image_features_small,mask_input=l_mask,grad_clipping=5)
#a recurrent layer (gru/lstm) with following checklist:
#    * takes word embeddings as an input
#    * has LSTM_UNITS units in the final layer
#    * has cell_init (or hid init for gru) set to converted image features
#    * mask_input = input_mask
#    * don't forget the grad clipping (~5-10)

#find out better recurrent architectures for bonus point

# %%
decoder.output_shape
predicted_probabilities=(DenseLayer(decoder,n_tokens,nonlinearity=lasagne.nonlinearities.softmax,num_leading_axes=2))

# %%
predicted_probabilities.output_shape
# Out:
# (None, None, 10373)

# %%
assert predicted_probabilities.output_shape == (None, None, 10373)

# %%
## Decoding of rnn hiden states
#from broadcast import BroadcastLayer,UnbroadcastLayer

##apply whatever comes next to each tick of each example in a batch. Equivalent to 2 reshapes
#broadcast_decoder_ticks = BroadcastLayer(decoder,(0,1))
#print ("broadcasted decoder shape = ",broadcast_decoder_ticks.output_shape)

# %%
##predict probabilities for next tokens
#predicted_probabilities_each_tick = <predict probabilities for each tick, using broadcasted_decoder_shape as an input. No reshaping needed here.>
## maybe a more complicated architecture will work better?

# %%
##un-broadcast back into (batch,tick,probabilities)
#predicted_probabilities = UnbroadcastLayer(predicted_probabilities_each_tick,
#                                           broadcast_layer=broadcast_decoder_ticks)

#print "output shape = ",predicted_probabilities.output_shape
#
##remove if you know what you're doing (e.g. 1d convolutions or fixed shape)
#assert predicted_probabilities.output_shape == (None, None, 10373)

# %% [markdown]
# ### Some tricks
# * If you train large network, it is usually a good idea to make a 2-stage prediction
#     1. (large recurrent state) -> (bottleneck e.g. 256)
#     2. (bottleneck) -> (vocabulary size)
#     * this way you won't need to store/train (large_recurrent_state x vocabulary size) matrix
# * Also maybe use Hierarchical Softmax?
#     * https://gist.github.com/justheuristic/581853c6d6b87eae9669297c2fb1052d

# %%
next_word_probas = <get network output>


predictions_flat = next_word_probas[:,:-1].reshape((-1,n_tokens))
reference_answers = sentences[:,1:].reshape((-1,))

#write symbolic loss function to train NN for
loss = <compute elementwise loss function>

#mean over non-PAD tokens
output_mask = sentence_mask[:,1:]
loss = (loss.reshape(reference_answers.shape)*output_mask).sum() / output_mask.sum()

# %%
#trainable NN weights
weights = get_all_params(predicted_probabilities,trainable=True)
updates = <parameter updates using your favorite algoritm>

# %%
#compile a functions for training and evaluation
#please not that your functions must accept image features as FIRST param and sentences as second one
train_step = <function that takes input sentence and image mask, outputs loss and updates weights>
val_step   = <function that takes input sentence and image mask and outputs loss>
#for val_step use deterministic=True if you have any dropout/noize

# %% [markdown]
# # Training
#
# * You first have to implement a batch generator
# * Than the network will get trained the usual way

# %%
captions = np.array(captions)

# %%
from random import choice

def generate_batch(images,captions,batch_size,max_caption_len=None):
    
    #sample random numbers for image/caption indicies
    random_image_ix = np.random.randint(0,len(images),size=batch_size)
    
    #get images
    batch_images = images[random_image_ix]
    
    #5-7 captions for each image
    captions_for_batch_images = captions[random_image_ix]
    
    #pick 1 from 5-7 captions for each image
    batch_captions = map(choice,captions_for_batch_images)
    
    #convert to matrix
    batch_captions_ix = as_matrix(batch_captions,max_len=max_caption_len)
    
    return batch_images, batch_captions_ix

# %%
generate_batch(img_codes,captions,3)

# %% [markdown]
# ### Main loop
# * We recommend you to periodically evaluate the network using the next "apply trained model" block
#  *  its safe to interrupt training, run a few examples and start training again

# %%
batch_size=50 #adjust me
n_epochs=100 #adjust me
n_batches_per_epoch = 50 #adjust me
n_validation_batches = 5 #how many batches are used for validation after each epoch

# %%
# !pip3 install --user tqdm

# %%
from tqdm import tqdm

for epoch in range(n_epochs):
    
    train_loss=0
    for _ in tqdm(range(n_batches_per_epoch)):
        train_loss += train_step(*generate_batch(img_codes,captions,batch_size))
    train_loss /= n_batches_per_epoch
    
    val_loss=0
    for _ in range(n_validation_batches):
        val_loss += val_step(*generate_batch(img_codes,captions,batch_size))
    val_loss /= n_validation_batches
    
    print('\nEpoch: {}, train loss: {}, val loss: {}'.format(epoch, train_loss, val_loss))

print("Finish :)")

# %% [markdown]
# ### apply trained model

# %%
# !pip3 install --user scikit-image

# %%
#the same kind you did last week, but a bit smaller
from pretrained_lenet import build_model,preprocess,MEAN_VALUES

# build googlenet
lenet = build_model()

#load weights
#lenet_weights = pickle.load(open(osp.join(DATA_DIR, 'data/blvc_googlenet.pkl')), encoding='latin1')['param values']
lenet_weights = np.load(osp.join(DATA_DIR, 'data/blvc_googlenet.npz'), encoding='latin1')['param values']
set_all_param_values(lenet["prob"], lenet_weights)

#compile get_features
cnn_input_var = lenet['input'].input_var
cnn_feature_layer = lenet['loss3/classifier']
get_cnn_features = theano.function([cnn_input_var], lasagne.layers.get_output(cnn_feature_layer))

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

#sample image
img = plt.imread(osp.join(DATA_DIR, 'data/Dog-and-Cat.jpg'))
img = preprocess(img)

# %%
#deprocess and show, one line :)
from pretrained_lenet import MEAN_VALUES
plt.imshow(np.transpose((img[0] + MEAN_VALUES)[::-1],[1,2,0]).astype('uint8'))

# %% [markdown]
# ## Generate caption

# %%
last_word_probas = <get network-predicted probas at last tick
#TRY OUT deterministic=True if you want more steady results

get_probs = theano.function([image_vectors,sentences], last_word_probas)

#this is exactly the generation function from week5 classwork,
#except now we condition on image features instead of words
def generate_caption(image,caption_prefix = ("START",),t=1,sample=True,max_len=100):
    image_features = get_cnn_features(image)
    caption = list(caption_prefix)
    for _ in range(max_len):
        
        next_word_probs = <obtain probabilities for next words>
        assert len(next_word_probs.shape) ==1 #must be one-dimensional
        #apply temperature
        next_word_probs = next_word_probs**t / np.sum(next_word_probs**t)

        if sample:
            next_word = np.random.choice(vocab,p=next_word_probs) 
        else:
            next_word = vocab[np.argmax(next_word_probs)]

        caption.append(next_word)

        if next_word=="#END#":
            break
            
    return caption

# %%
for i in range(10):
    print ' '.join(generate_caption(img,t=5.)[1:-1])

# %% [markdown]
# # Demo
# ### Find at least 10 images to test it on.
# * Seriously, that's part of an assignment. Go get at least 10 pictures to get captioned
# * Make sure it works okay on __simple__ images before going to something more comples
# * Photos, not animation/3d/drawings, unless you want to train CNN network on anime
# * Mind the aspect ratio (see what `preprocess` does to your image)

# %%
#apply your network on image sample you found
#
#

# %% [markdown]
# # grading
#
# * base 5 if it compiles and trains without exploding
# * +1 for finding representative set of reference examples
# * +2 for providing 10+ examples where network provides reasonable captions (at least sometimes :) )
#   * you may want to predict with sample=False and deterministic=True for consistent results
#   * kudos for submitting network params that reproduce it
# * +2 for providing 10+ examples where network fails IF you also got previous 10 examples right
#
#
# * bonus points for experiments with architecture and initialization (see above)
# * bonus points for trying out other pre-trained nets for captioning
# * a whole lot of bonus points if you also train via metric learning
#  * image -> vec
#  * caption -> vec (encoder, not decoder)
#  * loss = correct captions must be closer, wrong ones must be farther
#  * prediction = choose caption that is closest to image
# * a freaking whole lot of points if you also obtain statistically signifficant results the other way round
#  * take caption, get closest image
